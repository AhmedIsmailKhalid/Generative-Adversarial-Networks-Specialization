# %% [markdown]
# # Score-Based Generative Modeling
#
# *Please note that this is an optional notebook meant to introduce more advanced concepts. If you’re up for a challenge, take a look and don’t worry if you can’t follow everything. There is no code to implement—only some cool code for you to learn and run!*
#
# ### Goals
# This is a hitchhiker's guide to score-based generative models, a family of approaches based on [estimating gradients of the data distribution](https://arxiv.org/abs/1907.05600). They have obtained high-quality samples comparable to GANs (like below, figure from [this paper](https://arxiv.org/abs/2006.09011)) without requiring adversarial training, and are considered by some to be [the new contender to GANs](https://ajolicoeur.wordpress.com/the-new-contender-to-gans-score-matching-with-langevin-sampling/).
#
# ![ncsnv2](https://github.com/ermongroup/ncsnv2/blob/master/assets/samples.jpg?raw=true)

# %% [markdown]
# ## Introduction
#
# ### Score and Score-Based Models
# Given a probablity density function $p(\mathbf{x})$, we define the *score* as $$\nabla_\mathbf{x} \log p(\mathbf{x}).$$ As you might guess, score-based generative models are trained to estimate $\nabla_\mathbf{x} \log p(\mathbf{x})$. Unlike likelihood-based models such as flow models or autoregressive models, score-based models do not have to be normalized and are easier to parameterize. For example, consider a non-normalized statistical model $p_\theta(\mathbf{x}) = \frac{e^{-E_\theta(\mathbf{x})}}{Z_\theta}$, where $E_\theta(\mathbf{x}) \in \mathbb{R}$ is called the energy function and $Z_\theta$ is an unknown normalizing constant that makes $p_\theta(\mathbf{x})$ a proper probability density function. The energy function is typically parameterized by a flexible neural network. When training it as a likelihood model, we need to know the normalizing constant $Z_\theta$ by computing complex high-dimensional integrals, which is typically intractable. In constrast, when computing its score, we obtain $\nabla_\mathbf{x} \log p_\theta(\mathbf{x}) = -\nabla_\mathbf{x} E_\theta(\mathbf{x})$ which does not require computing the normalizing constant $Z_\theta$.
#
# In fact, any neural network that maps an input vector $\mathbf{x} \in \mathbb{R}^d$ to an output vector $\mathbf{y} \in \mathbb{R}^d$ can be used as a score-based model, as long as the output and input have the same dimensionality. This yields huge flexibility in choosing model architectures.
#
# ### Perturbing Data with a Diffusion Process
#
# In order to generate samples with score-based models, we need to consider a [diffusion process](https://en.wikipedia.org/wiki/Diffusion_process) that corrupts data slowly into random noise. Scores will arise when we reverse this diffusion process for sample generation. You will see this later in the notebook.
#
# A diffusion process is a [stochastic process](https://en.wikipedia.org/wiki/Stochastic_process#:~:text=A%20stochastic%20or%20random%20process%20can%20be%20defined%20as%20a,an%20element%20in%20the%20set.) similar to [Brownian motion](https://en.wikipedia.org/wiki/Brownian_motion). Their paths are like the trajectory of a particle submerged in a flowing fluid, which moves randomly due to unpredictable collisions with other particles. Let $\{\mathbf{x}(t) \in \mathbb{R}^d \}_{t=0}^T$ be a diffusion process, indexed by the continuous time variable $t\in [0,T]$. A diffusion process is governed by a stochastic differential equation (SDE), in the following form
#
# \begin{align*}
# d \mathbf{x} = \mathbf{f}(\mathbf{x}, t) d t + g(t) d \mathbf{w},
# \end{align*}
#
# where $\mathbf{f}(\cdot, t): \mathbb{R}^d \to \mathbb{R}^d$ is called the *drift coefficient* of the SDE, $g(t) \in \mathbb{R}$ is called the *diffusion coefficient*, and $\mathbf{w}$ represents the standard Brownian motion. You can understand an SDE as a stochastic generalization to ordinary differential equations (ODEs). Particles moving according to an SDE not only follows the deterministic drift $\mathbf{f}(\mathbf{x}, t)$, but are also affected by the random noise coming from $g(t) d\mathbf{w}$.
#
# For score-based generative modeling, we will choose a diffusion process such that $\mathbf{x}(0) \sim p_0$, where we have a dataset of i.i.d. samples, and $\mathbf{x}(T) \sim p_T$, for which we have a tractable form to sample from.
#
# ### Reversing the Diffusion Process Yields Score-Based Generative Models
# By starting from a sample from $p_T$ and reversing the diffusion process, we will be able to obtain a sample from $p_\text{data}$. Crucially, the reverse process is a diffusion process running backwards in time. It is given by the following reverse-time SDE
#
# \begin{align}
#   d\mathbf{x} = [\mathbf{f}(\mathbf{x}, t) - g^2(t)\nabla_{\mathbf{x}}\log p_t(\mathbf{x})] dt + g(t) d\bar{\mathbf{w}},
# \end{align}
#
# where $\bar{\mathbf{w}}$ is a Brownian motion in the reverse time direction, and $dt$ here represents an infinitesimal negative time step. Here $p_t(\mathbf{x})$ represents the distribution of $\mathbf{x}(t)$. This reverse SDE can be computed once we know the drift and diffusion coefficients of the forward SDE, as well as the score of $p_t(\mathbf{x})$ for each $t\in[0, T]$.
#
# The overall intuition of score-based generative modeling with SDEs can be summarized in the illustration below
# ![sde schematic](https://github.com/https-deeplearning-ai/GANs-Public/blob/master/diffusion_schematic.jpg?raw=true)
#
# ### Score Estimation
#
# Based on the above intuition, we can use the time-dependent score function $\nabla_\mathbf{x} \log p_t(\mathbf{x})$ to construct the reverse-time SDE, and then solve it numerically to obtain samples from $p_0$ using samples from a prior distribution $p_T$. We can train a time-dependent score-based model $s_\theta(\mathbf{x}, t)$ to approximate $\nabla_\mathbf{x} \log p_t(\mathbf{x})$, using the following weighted sum of [denoising score matching](http://www.iro.umontreal.ca/~vincentp/Publications/smdae_techreport.pdf) objectives.
#
# \begin{align}
# \min_\theta \mathbb{E}_{t\sim \mathcal{U}(0, T)} [\lambda(t) \mathbb{E}_{\mathbf{x}(0) \sim p_0(\mathbf{x})}\mathbf{E}_{\mathbf{x}(t) \sim p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))}[ \|s_\theta(\mathbf{x}(t), t) - \nabla_{\mathbf{x}(t)}\log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))\|_2^2]],
# \end{align}
# where $\mathcal{U}(0,T)$ is a uniform distribution over $[0, T]$, $p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))$ denotes the transition probability from $\mathbf{x}(0)$ to $\mathbf{x}(t)$, and $\lambda(t) \in \mathbb{R}^+$ denotes a continuous weighting function.
#
# In the objective, the expectation over $\mathbf{x}(0)$ can be estimated with empirical means over data samples from $p_0$. The expectation over $\mathbf{x}(t)$ can be estimated by sampling from $p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))$, which is efficient when the drift coefficient $\mathbf{f}(\mathbf{x}, t)$ is affine. The weight function $\lambda(t)$ is typically chosen to be inverse proportional to $\mathbb{E}[\|\nabla_{\mathbf{x}}\log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0)) \|_2^2]$.

# %% [markdown]
# ### Time-Dependent Score-Based Model
#
# There are no restrictions on the network architecture of time-dependent score-based models, except that their output should have the same dimensionality as the input, and they should be conditioned on time.
#
# Several useful tips on architecture choice:
# * It usually performs well to use the [U-net](https://arxiv.org/abs/1505.04597) architecture as the backbone of the score network $s_\theta(\mathbf{x}, t)$,
#
# * We can incorporate the time information via [Gaussian random features](https://arxiv.org/abs/2006.10739). Specifically, we first sample $\omega \sim \mathcal{N}(\mathbf{0}, s^2\mathbf{I})$ which is subsequently fixed for the model (i.e., not learnable). For a time step $t$, the corresponding Gaussian random feature is defined as
# \begin{align}
#   [\sin(2\pi \omega t) ; \cos(2\pi \omega t)],
# \end{align}
# where $[\vec{a} ; \vec{b}]$ denotes the concatenation of vector $\vec{a}$ and $\vec{b}$. This Gaussian random feature can be used as an encoding for time step $t$ so that the score network can condition on $t$ by incorporating this encoding. We will see this further in the code.
#
# * We can rescale the output of the U-net by $1/\sqrt{\mathbb{E}[\|\nabla_{\mathbf{x}}\log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0)) \|_2^2]}$. This is because the optimal $s_\theta(\mathbf{x}(t), t)$ has an $\ell_2$-norm close to $\mathbb{E}[\|\nabla_{\mathbf{x}}\log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))]\|_2$, and the rescaling helps capture the norm of the true score. Recall that the training objective contains sums of the form
# \begin{align*}
# \mathbf{E}_{\mathbf{x}(t) \sim p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))}[ \|s_\theta(\mathbf{x}(t), t) - \nabla_{\mathbf{x}(t)}\log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))\|_2^2]].
# \end{align*}
# Therefore, it is natural to expect that the optimal score model $s_\theta(\mathbf{x}, t) \approx \nabla_{\mathbf{x}(t)} \log p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0))$.
#
# * Use [exponential moving average](https://discuss.pytorch.org/t/how-to-apply-exponential-moving-average-decay-for-variables/10856/3) (EMA) of weights when sampling. This can greatly improve sample quality, but requires slightly longer training time, and requires more work in implementation. We do not include this in this tutorial, but highly recommend it when you employ score-based generative modeling to tackle more challenging real problems.

# %%
#@title Defining a time-dependent score-based model (double click to expand or collapse)

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class GaussianFourierProjection(nn.Module):
  """Gaussian random features for encoding time steps."""  
  def __init__(self, embed_dim, scale=8.):
    super().__init__()
    # Randomly sample weights during initialization. These weights are fixed 
    # during optimization and are not trainable.
    self.W = nn.Parameter(torch.randn(embed_dim // 2) * scale, requires_grad=False)
  def forward(self, x):
    x_proj = x[:, None] * self.W[None, :] * 2 * np.pi
    return torch.cat([torch.sin(x_proj), torch.cos(x_proj)], dim=-1)


class Dense(nn.Module):
  """A fully connected layer that reshapes outputs to feature maps."""
  def __init__(self, input_dim, output_dim):
    super().__init__()
    self.dense = nn.Linear(input_dim, output_dim)
  def forward(self, x):
    return self.dense(x)[..., None, None]


class ScoreNet(nn.Module):
  """A time-dependent score-based model built upon U-Net architecture."""

  def __init__(self, noise_scale, channels=[32, 64, 128, 256], embed_dim=256):
    """
      Initialize a time-dependent score-based network.

      noise_scale: 
        a function that takes time t and gives the variance of 
        the perturbation kernel p_{0t}(x(t) | x(0)).
      channels: 
        the number of channels for feature maps of each resolution.
      embed_dim:
        the dimensionality of Gaussian random feature embeddings.
    """
    super().__init__()
    # Gaussian random feature embedding layer for time
    self.embed = GaussianFourierProjection(embed_dim=embed_dim)    
    # Encoding layers where the resolution decreases
    self.conv1 = nn.Conv2d(1, channels[0], 3, stride=1, bias=False)
    self.dense1 = Dense(embed_dim, channels[0])
    self.gnorm1 = nn.GroupNorm(4, num_channels=channels[0])
    self.conv2 = nn.Conv2d(channels[0], channels[1], 3, stride=2, bias=False)
    self.dense2 = Dense(embed_dim, channels[1])
    self.gnorm2 = nn.GroupNorm(32, num_channels=channels[1])
    self.conv3 = nn.Conv2d(channels[1], channels[2], 3, stride=2, bias=False)
    self.dense3 = Dense(embed_dim, channels[2])
    self.gnorm3 = nn.GroupNorm(32, num_channels=channels[2])
    self.conv4 = nn.Conv2d(channels[2], channels[3], 3, stride=2, bias=False)
    self.dense4 = Dense(embed_dim, channels[3])
    self.gnorm4 = nn.GroupNorm(32, num_channels=channels[3])    

    # Decoding layers where the resolution increases
    self.tconv4 = nn.ConvTranspose2d(channels[3], channels[2], 3, stride=2, bias=False)
    self.dense5 = Dense(embed_dim, channels[2])
    self.tgnorm4 = nn.GroupNorm(32, num_channels=channels[2])
    self.tconv3 = nn.ConvTranspose2d(channels[2] + channels[2], channels[1], 3, stride=2, bias=False, output_padding=1)    
    self.dense6 = Dense(embed_dim, channels[1])
    self.tgnorm3 = nn.GroupNorm(32, num_channels=channels[1])
    self.tconv2 = nn.ConvTranspose2d(channels[1] + channels[1], channels[0], 3, stride=2, bias=False, output_padding=1)    
    self.dense7 = Dense(embed_dim, channels[0])
    self.tgnorm2 = nn.GroupNorm(32, num_channels=channels[0])
    self.tconv1 = nn.ConvTranspose2d(channels[0] + channels[0], 1, 3, stride=1)
    
    # The swish activation function
    self.act = lambda x: x * torch.sigmoid(x)
    self.noise_scale = noise_scale
  
  def forward(self, x, t): 
    # Obtain the Gaussian random feature embedding for t   
    embed = self.act(self.embed(t))    
    # Encoding path
    h1 = self.conv1(x)    
    ## Incorporate information from t
    h1 += self.dense1(embed)
    ## Group normalization
    h1 = self.gnorm1(h1)
    h1 = self.act(h1)
    h2 = self.conv2(h1)
    h2 += self.dense2(embed)
    h2 = self.gnorm2(h2)
    h2 = self.act(h2)
    h3 = self.conv3(h2)
    h3 += self.dense3(embed)
    h3 = self.gnorm3(h3)
    h3 = self.act(h3)
    h4 = self.conv4(h3)
    h4 += self.dense4(embed)
    h4 = self.gnorm4(h4)
    h4 = self.act(h4)

    # Decoding path
    h = self.tconv4(h4)
    ## Skip connection from the encoding path
    h += self.dense5(embed)
    h = self.tgnorm4(h)
    h = self.act(h)
    h = self.tconv3(torch.cat([h, h3], dim=1))
    h += self.dense6(embed)
    h = self.tgnorm3(h)
    h = self.act(h)
    h = self.tconv2(torch.cat([h, h2], dim=1))
    h += self.dense7(embed)
    h = self.tgnorm2(h)
    h = self.act(h)
    h = self.tconv1(torch.cat([h, h1], dim=1))

    # Normalize output based on the norm of perturbation kernels.
    h = h / self.noise_scale(t)[:, None, None, None]
    return h

# %% [markdown]
# ## Training with Weighted Sum of Denoising Score Matching Objectives
#
# Now let's get our hands dirty on training. First of all, we need to specify an SDE that perturbs the data distribution $p_0$ to a prior distribution $p_T$. We choose the following SDE
# \begin{align*}
# d \mathbf{x} = \sqrt{\frac{d [\sigma^2(t)]}{dt}} d\mathbf{w},
# \end{align*}
# where $\sigma(t) = \sigma_{\text{min}}(\frac{\sigma_{\text{max}}}{\sigma_{\text{min}}})^t$, $t\in[0,1]$. In this case,
# \begin{align*}
# p_{0t}(\mathbf{x}(t) \mid \mathbf{x}(0)) = \mathcal{N}(\mathbf{x}(t); \mathbf{x}(0), [\sigma^2(t) - \sigma^2(0)]\mathbf{I})
# \end{align*}
# and $\lambda(t) \propto \sigma^2(t) - \sigma^2(0)$.
#
# When $\sigma_{\text{max}}$ is large enough, the distribution of $p_1$ is
# \begin{align*}
# \int p_0(\mathbf{y})\mathcal{N}(\mathbf{x}; \mathbf{y}, [\sigma_{\text{max}}^2 - \sigma_{\text{min}}^2]\mathbf{I}) d \mathbf{y} \approx \mathbf{N}(\mathbf{x}; \mathbf{0}, [\sigma_{\text{max}}^2 - \sigma_{\text{min}}^2]\mathbf{I}),
# \end{align*}
# which is easy to sample from.
#
# Intuitively, this SDE captures a continuum of Gaussian perturbations with variance function $\sigma(t)^2 - \sigma^2(0)$, where $\sigma(t)$ is a strictly increasing function that grows exponentially fast. This continuum of perturbations allows us to gradually transfer samples from a data distribution $p_0$ to a simple Gaussian distribution $p_1$.

# %%
#@title Loss function (double click to expand or collapse)
def noise_scale(t, sigma_min=0.01, sigma_max=10, grad=False):
  """
  Compute quantities related to the perturbation kernel p_{0t}(x(t) | x(0)).

  t: a vector of time steps.
  sigma_min: the minimum value of the sigma function.
  sigma_max: the maximum value of the sigma function.
  grad: if False, only return the variance of p_{0t}(x(t) | x(0)). 
    Otherwise return both the variance and the gradient of sigma^2(t).
    This gradient will be useful for sample generation.
  """
  noise = sigma_min * (sigma_max / sigma_min)**t
  if not grad:
    return torch.sqrt(noise**2 - sigma_min**2)
  else:
    dnoise_dt = sigma_min * (sigma_max / sigma_min)**t * np.log(sigma_max/sigma_min)
    dnoise2_dt = 2 * noise * dnoise_dt
    return torch.sqrt(noise**2 - sigma_min**2), dnoise2_dt

def loss_func(model, x, noise_scale, eps=1e-3):
  """
  The loss function for training score-based generative models.

  model: a PyTorch model instance that represents a time-dependent score-based model.
  x: a mini-batch of input images.
  noise_scale: a function that computes the variance of perturbation kernels.
  eps: a tolerance value for numerical stability.
  """
  random_t = torch.rand(x.shape[0], device=x.device) * (1. - eps) + eps
  noise_scales = noise_scale(random_t)
  z = torch.randn_like(x)
  perturbed_x = x + z * noise_scales[:, None, None, None]
  score = model(perturbed_x, random_t)
  loss = torch.sum((score * noise_scales[:, None, None, None] + z).reshape(x.shape[0], -1)**2, dim=-1).mean()
  return loss

# %%
#@title Training (double click to expand or collapse)

import torch
import functools
from torch.optim import Adam
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torchvision.datasets import MNIST
import tqdm

device = 'cuda' #@param ['cuda', 'cpu'] {'type':'string'}

sigma_min = 0.01 #@param {'type':'number'}
sigma_max = 22 #@param {'type':'number'}
noise_scale_func = functools.partial(noise_scale, sigma_min=sigma_min, sigma_max=sigma_max, grad=False)
score_model = torch.nn.DataParallel(ScoreNet(noise_scale=noise_scale_func))
score_model = score_model.to(device)

n_epochs =  50 #@param {'type':'integer'}
## size of a mini-batch
batch_size =  32 #@param {'type':'integer'}
## learning rate
lr=1e-4 #@param {'type':'number'}

dataset = MNIST('.', train=True, transform=transforms.ToTensor(), download=True)
data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=4)

optimizer = Adam(score_model.parameters(), lr=lr)
for epoch in range(n_epochs):
  avg_loss = 0.
  num_items = 0
  for x, y in tqdm.notebook.tqdm(data_loader):
    optimizer.zero_grad()
    x = x.to(device)    
    loss = loss_func(score_model, x, noise_scale_func)
    loss.backward()
    optimizer.step()
    avg_loss += loss.item() * x.shape[0]
    num_items += x.shape[0]
  # Print the averaged training loss so far.
  print(f'epoch: {epoch}, average loss: {avg_loss / num_items}')
  # Save one checkpoint after each epoch of training.
  torch.save(score_model.state_dict(), f'ckpt.pth')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 0, average loss: 385.38379298502605
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 1, average loss: 169.2812524617513
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 2, average loss: 134.96670705973307
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 3, average loss: 120.18092231445313
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 4, average loss: 110.90156045125326
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 5, average loss: 103.36416658935546
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 6, average loss: 98.93995713297527
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 7, average loss: 94.32716554768881
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 8, average loss: 91.52310501098633
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 9, average loss: 88.30215564575195
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 10, average loss: 85.89739788208009
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 11, average loss: 83.363864453125
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 12, average loss: 82.29969951171876
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 13, average loss: 79.74208435465495
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 14, average loss: 79.16185733235677
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 15, average loss: 77.33749239400228
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 16, average loss: 76.86937318725586
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 17, average loss: 75.47137581176757
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 18, average loss: 73.87137966715495
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 19, average loss: 73.0908658396403
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 20, average loss: 71.44915935872396
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 21, average loss: 70.86973952941895
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 22, average loss: 69.40125533040364
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 23, average loss: 69.13981457112631
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 24, average loss: 68.48093526204427
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 25, average loss: 67.54151135660807
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 26, average loss: 66.46452871602376
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 27, average loss: 66.10339775390625
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 28, average loss: 65.00912614339192
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 29, average loss: 64.40760010986328
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 30, average loss: 64.10179983215332
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 31, average loss: 63.8198496866862
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 32, average loss: 63.43439471435547
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 33, average loss: 62.83214105936686
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 34, average loss: 62.553961326090494
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 35, average loss: 62.35596174825032
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 36, average loss: 61.69863636474609
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 37, average loss: 61.29666221211751
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 38, average loss: 61.02956051127116
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 39, average loss: 60.51826075337728
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 40, average loss: 60.27943378295898
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 41, average loss: 59.888646212768556
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 42, average loss: 59.351622529093426
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 43, average loss: 59.62506807047526
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 44, average loss: 59.127342802937825
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 45, average loss: 58.783113010660806
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 46, average loss: 58.53715802103678
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 47, average loss: 58.237214647420245
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 48, average loss: 57.79328476053874
#   0%|          | 0/1875 [00:00<?, ?it/s]
# epoch: 49, average loss: 57.969199029541016

# %% [markdown]
# ## Sampling with Numerical SDE Solvers
# Recall that for any SDE of the form
# \begin{align*}
# d \mathbf{x} = \mathbf{f}(\mathbf{x}, t) dt + g(t) d\mathbf{w},
# \end{align*}
# the reverse-time SDE is given by
# \begin{align*}
# d \mathbf{x} = [\mathbf{f}(\mathbf{x}, t) + g(t)^2 \nabla_\mathbf{x} \log p_t(\mathbf{x})] dt + g(t) d \bar{\mathbf{w}}.
# \end{align*}
# Since we have chosen the forward SDE to be
# \begin{align*}
# d \mathbf{x} = \sqrt{\frac{d [\sigma^2(t)]}{dt}} d\mathbf{w},
# \end{align*}
# where $\sigma(t) = \sigma_{\text{min}}(\frac{\sigma_{\text{max}}}{\sigma_{\text{min}}})^t$, $t\in[0,1]$. The reverse-time SDE is given by
# \begin{align*}
# d\mathbf{x} = -\frac{d[\sigma^2(t)]}{dt} \nabla_\mathbf{x} \log p_t(\mathbf{x}) dt + \sqrt{\frac{d[\sigma^2(t)]}{d t}} d \bar{\mathbf{w}}.
# \end{align*}
# To sample from our time-dependent score-based model $s_\theta(\mathbf{x}, t)$, we can first draw a sample from $p_1 \approx \mathbf{N}(\mathbf{x}; \mathbf{0}, [\sigma_{\text{max}}^2 - \sigma_{\text{min}}^2]\mathbf{I})$, and then solve the reverse-time SDE with numerical methods.
#
# Specifically, using our time-dependent score-based model, the reverse-time SDE can be approximated by
# \begin{align*}
# d\mathbf{x} = -\frac{d[\sigma^2(t)]}{dt} s_\theta(\mathbf{x}, t) dt + \sqrt{\frac{d[\sigma^2(t)]}{d t}} d \bar{\mathbf{w}}
# \end{align*}
#
# Next, one can use numerical methods to solve for the reverse-time SDE, such as the [Euler-Maruyama](https://en.wikipedia.org/wiki/Euler%E2%80%93Maruyama_method) approach. It is based on a simple discretization to the SDE, replacing $dt$ with $\Delta t$ and $d \mathbf{w}$ with $\mathbf{z} \sim \mathcal{N}(\mathbf{0}, g^2(t) \Delta t \mathbf{I})$. When applied to our reverse-time SDE, we can obtain the following iteration rule
# \begin{align}
# \mathbf{x}_{t-\Delta t} = \mathbf{x}_t + \frac{d[\sigma^2(t)]}{dt}s_\theta(\mathbf{x}_t, t)\Delta t + \sqrt{\frac{d[\sigma^2(t)]}{dt}\Delta t} \mathbf{z}_t,
# \end{align}
# where $\mathbf{z}_t \sim \mathcal{N}(\mathbf{0}, \mathbf{I})$.

# %% [markdown]
# ## Sampling with Predictor-Corrector Methods
#
# Aside from generic numerical SDE solvers, we can leverage special properties of our reverse-time SDE for better solutions. Since we have an estimate of the score of $p_t(\mathbf{x}(t))$ via the score-based model, i.e., $s_\theta(\mathbf{x}, t) \approx \nabla_{\mathbf{x}(t)} \log p_t(\mathbf{x}(t))$, we can leverage score-based MCMC approaches, such as Langevin MCMC, to correct the solution obtained by numerical SDE solvers.
#
# Score-based MCMC approaches can produce samples from a distribution $p(\mathbf{x})$ once its score $\nabla_\mathbf{x} \log p(\mathbf{x})$ is known. For example, Langevin MCMC operates by running the following iteration rule for $i=1,2,\cdots, N$:
# \begin{align*}
# \mathbf{x}_{i+1} = \mathbf{x}_{i} + \epsilon \nabla_\mathbf{x} \log p(\mathbf{x}_i) + \sqrt{2\epsilon} \mathbf{z}_i,
# \end{align*}
# where $\mathbf{z}_i \sim \mathcal{N}(\mathbf{0}, \mathbf{I})$, $\epsilon > 0$ is the step size, and $\mathbf{x}_1$ is initialized from any prior distribution $\pi(\mathbf{x}_1)$. When $N\to\infty$ and $\epsilon \to 0$, the final value $\mathbf{x}_{N+1}$ becomes a sample from $p(\mathbf{x})$ under some regularity conditions. Therefore, given $s_\theta(\mathbf{x}, t) \approx \nabla_\mathbf{x} \log p_t(\mathbf{x})$, we can get an approximate sample from $p_t(\mathbf{x})$ by running several steps of Langevin MCMC, replacing $\nabla_\mathbf{x} \log p_t(\mathbf{x})$ with $s_\theta(\mathbf{x}, t)$ in the iteration rule.
#
# Predictor-Corrector samplers combine both numerical solvers for the reverse-time SDE and the Langevin MCMC approach. In particular, we first apply one step of numerical SDE solver to obtain $\mathbf{x}_{t-\Delta t}$ from $\mathbf{x}_t$, which is called the "predictor" step. Next, we apply several steps of Langevin MCMC to refine $\mathbf{x}_t$, such that $\mathbf{x}_t$ becomes a more accurate sample from $p_{t-\Delta t}(\mathbf{x})$. This is the "corrector" step as the MCMC helps reduce the error of the numerical SDE solver.

# %% [markdown]
# ## Sampling with Numerical ODE Solvers
#
# For any SDE of the form
# \begin{align*}
# d \mathbf{x} = \mathbf{f}(\mathbf{x}, t) d t + g(t) d \mathbf{w},
# \end{align*}
# there exists an associated ordinary differential equation (ODE)
# \begin{align*}
# d \mathbf{x} = \bigg[\mathbf{f}(\mathbf{x}, t) - \frac{1}{2}g(t)^2 \nabla_\mathbf{x} \log p_t(\mathbf{x})\bigg] dt,
# \end{align*}
# such that their trajectories have the same mariginal probability density $p_t(\mathbf{x})$. We call this ODE the *probability flow ODE*.
#
# Therefore, we can start from a sample from $p_T$, integrate the ODE in the reverse time direction, and then get a sample from $p_0 = p_\text{data}$. In particular, for our chosen forward SDE, we can integrate the following SDE from $t=T$ to $0$ for sample generation
# \begin{align*}
# d\mathbf{x} =  -\frac{1}{2}\frac{d[\sigma^2(t)]}{d t} s_\theta(\mathbf{x}, t) dt.
# \end{align*}
# This can be done using many heavily-optimized black-box ODE solvers provided by packages such as `scipy`.

# %%
#@title SDE sampling (double click to expand or collapse)

## The number of sampling steps.
num_steps = 500 #@param {'type':'integer'}
def sde_sampler(score_model, noise_scale, batch_size=64, num_steps=num_steps, device='cuda'):
  """
  Generate samples from score-based models with numerical SDE solvers.

  score_model: a PyTorch model that represents the time-dependent score-based model.
  noise_scale: a function that gives a tuple: (the variance of p_{0t}(x(t) | x(0)) and
    , the gradient of sigma^2(t) ).
  batch_size: the number of samplers to generate by calling this function once.
  num_steps: the number of sampling steps. Also equivalent to the number of discretized time steps.
  device: 'cuda' for running on GPUs, and 'cpu' for running on CPUs.
  """
  t = torch.ones(batch_size, device=device)
  init_x = torch.randn(batch_size, 1, 28, 28, device=device) * noise_scale(t)[0][:, None, None, None]
  time_steps = np.linspace(1., 1e-3, num_steps)
  step_size = time_steps[0] - time_steps[1]
  x = init_x
  with torch.no_grad():
    for time_step in tqdm.notebook.tqdm(time_steps):      
      batch_time_step = torch.ones(batch_size, device=device) * time_step
      next_x = x + noise_scale(batch_time_step)[1][:, None, None, None] * score_model(x, batch_time_step) * step_size
      next_x = next_x + torch.sqrt(noise_scale(batch_time_step)[1] * step_size)[:, None, None, None] * torch.randn_like(x)
      x = next_x       
    return x

# %%
#@title PC sampling (double click to expand or collapse)

signal_to_noise_ratio = 0.15 #@param {'type':'number'}

## The number of sampling steps.
num_steps = 500 #@param {'type':'integer'}
def pc_sampler(score_model, noise_scale, batch_size=64, num_steps=num_steps, snr=signal_to_noise_ratio, device='cuda'):
  """
  Generate samples from score-based models with Predictor-Corrector method.

  score_model: a PyTorch model that represents the time-dependent score-based model.
  noise_scale: a function that gives a tuple: (the variance of p_{0t}(x(t) | x(0)) and
    , the gradient of sigma^2(t) ).
  batch_size: the number of samplers to generate by calling this function once.
  num_steps: the number of sampling steps. Also equivalent to the number of discretized time steps.
  device: 'cuda' for running on GPUs, and 'cpu' for running on CPUs.
  """
  t = torch.ones(batch_size, device=device)
  init_x = torch.randn(batch_size, 1, 28, 28, device=device) * noise_scale(t)[0][:, None, None, None]
  time_steps = np.linspace(1., 1e-3, num_steps)
  step_size = time_steps[0] - time_steps[1]
  x = init_x
  with torch.no_grad():
    for time_step in tqdm.notebook.tqdm(time_steps):      
      # Corrector step
      batch_time_step = torch.ones(batch_size, device=device) * time_step
      next_x = x + noise_scale(batch_time_step)[1][:, None, None, None] * score_model(x, batch_time_step) * step_size
      next_x = next_x + torch.sqrt(noise_scale(batch_time_step)[1] * step_size)[:, None, None, None] * torch.randn_like(x)
      x = next_x 

      # Predictor step
      grad = score_model(x, batch_time_step)
      grad_norm = torch.norm(grad.reshape(grad.shape[0], -1), dim=-1).mean()
      noise_norm = np.sqrt(np.prod(x.shape[1:]))
      langevin_step_size = 2 * (snr * noise_norm / grad_norm)**2
      x = x + langevin_step_size * grad + torch.sqrt(2 * langevin_step_size) * torch.randn_like(x)      
    return x

# %%
#@title ODE sampling (double click to expand or collapse)

from scipy import integrate

## The error tolerance for the black-box ODE solver
error_tolerance = 1e-5 #@param {'type': 'number'}
def ode_sampler(score_model, noise_scale, batch_size=64, atol=error_tolerance, rtol=error_tolerance, device='cuda', z=None):
  """
  Generate samples from score-based models with black-box ODE solvers.

  score_model: a PyTorch model that represents the time-dependent score-based model.
  noise_scale: a function that gives a tuple: (the variance of p_{0t}(x(t) | x(0)) and
    , the gradient of sigma^2(t) ).
  batch_size: the number of samplers to generate by calling this function once.
  atol: tolerance of absolute errors.
  rtol: tolerance of relative errors.
  device: 'cuda' for running on GPUs, and 'cpu' for running on CPUs.
  z: the latent code that governs the final sample. If None, we start from p_1;
    otherwise, we start from the given z.
  """
  t = torch.ones(batch_size, device=device)
  # Create the latent code
  if z is None:
    init_x = torch.randn(batch_size, 1, 28, 28, device=device) * noise_scale(t)[0][:, None, None, None]
  else:
    init_x = z
    
  shape = init_x.shape

  def score_eval_wrapper(sample, time_steps):
    """A wrapper of the score-based model for use by the ODE solver."""
    sample = torch.tensor(sample, device=device, dtype=torch.float32).reshape(shape)
    time_steps = torch.tensor(time_steps, device=device, dtype=torch.float32).reshape((sample.shape[0], ))    
    with torch.no_grad():    
      score = score_model(sample, time_steps)
    return score.cpu().numpy().reshape((-1,)).astype(np.float64)
  
  def ode_func(t, x):        
    """The ODE function for use by the ODE solver."""
    time_steps = np.ones((shape[0],)) * t
    
    return  -0.5 * noise_scale(torch.tensor(t))[1].cpu().numpy() * score_eval_wrapper(x, time_steps)    
  
  # Run the black-box ODE solver.
  res = integrate.solve_ivp(ode_func, (1., 1e-2), init_x.reshape(-1).cpu().numpy(), rtol=rtol, atol=atol, method='RK45')  
  print(f"Number of function evaluations: {res.nfev}")
  x = torch.tensor(res.y[:, -1], device=device).reshape(shape)

  return x

# %%
#@title Sampling (double click to expand or collapse)

from torchvision.utils import make_grid

## Load the pre-trained checkpoint from disk.
device = 'cuda' #@param ['cuda', 'cpu'] {'type':'string'}
ckpt = torch.load('ckpt.pth', map_location=device)
score_model.load_state_dict(ckpt)

noise_scale_func = functools.partial(noise_scale, sigma_min=sigma_min, sigma_max=sigma_max, grad=True)
sample_batch_size = 64 #@param {'type':'integer'}
sampler = pc_sampler #@param ['sde_sampler', 'pc_sampler', 'ode_sampler'] {'type': 'raw'}

## Generate samples using the specified sampler.
samples = sampler(score_model, noise_scale_func, sample_batch_size, device=device)

## Sample visualization.
samples = samples.clamp(0.0, 1.0)
import matplotlib.pyplot as plt
sample_grid = make_grid(samples, nrow=int(np.sqrt(sample_batch_size)))

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %% [markdown]
# ## Likelihood Computation
#
# A by-product of the probability flow ODE formulation is likelihood computation. Suppose we have a differentiable one-to-one mapping $\mathbf{h}$ that transforms a data sample $\mathbf{x} \sim p_0$ to a prior distribution $\mathbf{h}(\mathbf{x}) \sim p_1$. We can compute the likelihood of $p_0(\mathbf{x})$ via the following [change-of-variable formula](https://en.wikipedia.org/wiki/Probability_density_function#Function_of_random_variables_and_change_of_variables_in_the_probability_density_function)
# \begin{align*}
# p_0(\mathbf{x}) = p_1(\mathbf{h}(\mathbf{x})) |\operatorname{det}(J_\mathbf{h}(\mathbf{x}))|,
# \end{align*}
# where $J_\mathbf{h}(\mathbf{x})$ represents the Jacobian of the mapping $\mathbf{h}$, and we assume it is efficient to evaluate the likelihood of the prior distribution $p_1$.
#
# Similarly, an ODE is also a one-to-one mapping from $\mathbf{x}(0)$ to $\mathbf{x}(1)$. For ODEs of the form
# \begin{align*}
# d \mathbf{x} = \mathbf{f}(\mathbf{x}, t) dt,
# \end{align*}
# there exists an [instantaneous change-of-variable formula](https://arxiv.org/abs/1806.07366) that connects the probability of $p_0(\mathbf{x})$ and $p_1(\mathbf{x})$, given by
# \begin{align*}
# p_0 (\mathbf{x}(0)) = e^{\int_0^1 \operatorname{div} \mathbf{f}(\mathbf{x}(t), t) d t} p_1(\mathbf{x}(1)),
# \end{align*}
# where $\operatorname{div}$ denotes the divergence function (trace of Jacobian).
#
# In practice, this divergence function can be hard to evaluate for general vector-valued function $\mathbf{f}$, but we can use an unbiased estimator, named [Skilling-Hutchinson estimator](http://blog.shakirm.com/2015/09/machine-learning-trick-of-the-day-3-hutchinsons-trick/), to approximate the trace. Let $\boldsymbol \epsilon \sim \mathcal{N}(\mathbf{0}, \mathbf{I})$. The Skilling-Hutchinson estimator is based on the fact that
# \begin{align*}
# \operatorname{div} \mathbf{f}(\mathbf{x}) = \mathbb{E}_{\boldsymbol\epsilon \sim \mathcal{N}(\mathbf{0}, \mathbf{I})}[\boldsymbol\epsilon^\intercal  J_\mathbf{f}(\mathbf{x}) \boldsymbol\epsilon].
# \end{align*}
# Therefore, we can simply sample a random vector $\boldsymbol \epsilon \sim \mathcal{N}(\mathbf{0}, \mathbf{I})$, and then use $\boldsymbol \epsilon^\intercal J_\mathbf{f}(\mathbf{x}) \boldsymbol \epsilon$ to estimate the divergence of $\mathbf{f}(\mathbf{x})$. This estimator only requires computing the Jacobian-vector product $J_\mathbf{f}(\mathbf{x})\boldsymbol \epsilon$, which is typically efficient.
#
# As a result, for our probability flow ODE, we can compute the (log) data likelihood with the following
# \begin{align*}
# \log p_0(\mathbf{x}(0)) = \log p_1(\mathbf{x}(1)) -\frac{1}{2}\int_0^1 \frac{d[\sigma^2(t)]}{dt} \operatorname{div} s_\theta(\mathbf{x}(t), t) dt.
# \end{align*}
# With the Skilling-Hutchinson estimator, we can compute the divergence via
# \begin{align*}
# \operatorname{div} s_\theta(\mathbf{x}(t), t) = \mathbb{E}_{\boldsymbol\epsilon \sim \mathcal{N}(\mathbf{0}, \mathbf{I})}[\boldsymbol\epsilon^\intercal  J_{s_\theta}(\mathbf{x}(t), t) \boldsymbol\epsilon].
# \end{align*}
# Afterwards, we can compute the integral with numerical integrators. This gives us an unbiased estimate to the true data likelihood, and we can make it more and more accurate when we run it multiple times and take the average. The numerical integrator requires $\mathbf{x}(t)$ as a function of $t$, which can be obtained by solving the original probability flow ODE.

# %%
#@title Likelihood function (double click to expand or collapse)

def prior_likelihood(z, sigma):
  """The likelihood of a Gaussian distribution with mean zero and 
      standard deviation sigma."""
  shape = z.shape
  N = np.prod(shape[1:])
  return -N / 2. * torch.log(2*np.pi*sigma**2) - torch.sum(z**2, dim=(1,2,3)) / (2 * sigma**2)

def ode_likelihood(x, score_model, noise_scale, batch_size=64, device='cuda'):

  # Draw the random Gaussian sample for Skilling-Hutchinson's estimator.
  epsilon = torch.randn_like(x)
      
  def divergence_eval(sample, time_steps, epsilon):      
    """Compute the divergence of the score-based model with Skilling-Hutchinson."""
    with torch.enable_grad():
      sample.requires_grad_(True)
      score_e = torch.sum(score_model(sample, time_steps) * epsilon)
      grad_score_e = torch.autograd.grad(score_e, sample)[0]
    return torch.sum(grad_score_e * epsilon, dim=(1, 2, 3))    
  
  shape = x.shape

  def score_eval_wrapper(sample, time_steps):
    """A wrapper for evaluating the score-based model for the black-box ODE solver."""
    sample = torch.tensor(sample, device=device, dtype=torch.float32).reshape(shape)
    time_steps = torch.tensor(time_steps, device=device, dtype=torch.float32).reshape((sample.shape[0], ))    
    with torch.no_grad():    
      score = score_model(sample, time_steps)
    return score.cpu().numpy().reshape((-1,)).astype(np.float64)
  
  def divergence_eval_wrapper(sample, time_steps):
    """A wrapper for evaluating the divergence of score for the black-box ODE solver."""
    with torch.no_grad():
      # Obtain x(t) by solving the probability flow ODE.
      sample = torch.tensor(sample, device=device, dtype=torch.float32).reshape(shape)
      time_steps = torch.tensor(time_steps, device=device, dtype=torch.float32).reshape((sample.shape[0], ))    
      # Compute likelihood.
      div = divergence_eval(sample, time_steps, epsilon)
      return div.cpu().numpy().reshape((-1,)).astype(np.float64)
  
  def ode_func(t, x):
    """The ODE function for the black-box solver."""
    time_steps = np.ones((shape[0],)) * t    
    sample = x[:-shape[0]]
    logp = x[-shape[0]:]
    sample_grad = -0.5 * noise_scale(torch.tensor(t))[1].cpu().numpy() * score_eval_wrapper(sample, time_steps)
    logp_grad = -0.5 * noise_scale(torch.tensor(t))[1].cpu().numpy() * divergence_eval_wrapper(sample, time_steps)
    return np.concatenate([sample_grad, logp_grad], axis=0)

  init = np.concatenate([x.cpu().numpy().reshape((-1,)), np.zeros((shape[0],))], axis=0)
  # Black-box ODE solver
  res = integrate.solve_ivp(ode_func, (1e-3, 1.), init, rtol=1e-5, atol=1e-5, method='RK45')  
  zp = torch.tensor(res.y[:, -1], device=device)
  z = zp[:-shape[0]].reshape(shape)
  delta_logp = zp[-shape[0]:].reshape(shape[0])
  sigma_max = noise_scale(torch.ones((), device=device))[0]
  prior_logp = prior_likelihood(z, sigma_max)
  bpd = -(prior_logp + delta_logp) / np.log(2)
  N = np.prod(shape[1:])
  bpd = bpd / N + 8.
  return z, bpd

# %%
#@title Computing likelihood on the dataset (double click to expand or collapse)

device = 'cuda' #@param ['cuda', 'cpu'] {'type':'string'}

ckpt = torch.load('ckpt.pth', map_location=device)
score_model.load_state_dict(ckpt)

noise_scale_func = functools.partial(noise_scale, sigma_min=sigma_min, sigma_max=sigma_max, grad=True)

all_bpds = 0.
all_items = 0
try:
  for x, _ in tqdm.notebook.tqdm(data_loader):
    x = x.to(device)
    # uniform dequantization
    x = (x * 255. + torch.rand_like(x)) / 256.    
    _, bpd = ode_likelihood(x, score_model, noise_scale_func, x.shape[0], device=device)
    all_bpds += bpd.sum()
    all_items += bpd.shape[0]
    print(f"bpd (running average): {all_bpds / all_items}")
  print(f"bpd (full average): {all_bpds/all_items}")
except KeyboardInterrupt:
  # Remove the error message when interuptted by keyboard or GUI.
  pass
# Out:
#   0%|          | 0/1875 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# bpd (running average): 2.448278623233607
# bpd (running average): 2.1977393704026182
# bpd (running average): 2.203923523450996
# bpd (running average): 2.176194115876587
# bpd (running average): 2.1956380445443933
# bpd (running average): 2.1773103038015664
# bpd (running average): 2.1797895239327696
# bpd (running average): 2.1503614921643868
# bpd (running average): 2.146495249079379
# bpd (running average): 2.1329029443421335
# bpd (running average): 2.1377571066708154
# bpd (running average): 2.1282122762845814
# bpd (running average): 2.1315424483280037
# bpd (running average): 2.135415825506101
# bpd (running average): 2.1303033865422374
# bpd (running average): 2.121564606662629
# bpd (running average): 2.11012577197725
# bpd (running average): 2.107587629575148
# bpd (running average): 2.102445251773852
# bpd (running average): 2.1026671777580357
# bpd (running average): 2.0977302739671675
# bpd (running average): 2.0912416992891414
# bpd (running average): 2.0854356080108394
# bpd (running average): 2.076285766595822
# bpd (running average): 2.0725537270359693
# bpd (running average): 2.0755875501450807
# bpd (running average): 2.0747826025664664
# bpd (running average): 2.0763722795317268
# bpd (running average): 2.0774712643963533
# bpd (running average): 2.074048705071638
# bpd (running average): 2.0742910891367083
# bpd (running average): 2.0710960922316364
# bpd (running average): 2.075696618575006
# bpd (running average): 2.0787004182627786
# bpd (running average): 2.079008369695649
# bpd (running average): 2.0789250911378123
# bpd (running average): 2.0818775212344547
# bpd (running average): 2.0806454042567024
# bpd (running average): 2.08216586036224
# bpd (running average): 2.0826150356325455
# bpd (running average): 2.0825894973552272
# bpd (running average): 2.0796162928578945
# bpd (running average): 2.0777558180466538
# bpd (running average): 2.079685346776005
# bpd (running average): 2.0838835339505493
# bpd (running average): 2.082606027593394
# bpd (running average): 2.082983985342929
# bpd (running average): 2.0858941765119923
# bpd (running average): 2.0906477120384257
# bpd (running average): 2.0903847097471546
# bpd (running average): 2.0925314249428686
# bpd (running average): 2.0875509373989414
# bpd (running average): 2.083173876528407
# bpd (running average): 2.08274355228293
# bpd (running average): 2.0875456501961955
# bpd (running average): 2.086496587183171
# bpd (running average): 2.086025752815397
# bpd (running average): 2.085821287262027
# bpd (running average): 2.0871963614496316
# bpd (running average): 2.087558469134771
# bpd (running average): 2.0869327617913447
# bpd (running average): 2.085264509893368
# bpd (running average): 2.0862012212764816
# bpd (running average): 2.083843144651336
# bpd (running average): 2.0822432774663446
# bpd (running average): 2.0831616006155476
# bpd (running average): 2.081011815509867
# bpd (running average): 2.0816327326697857
# bpd (running average): 2.0838601284908727
# bpd (running average): 2.086589146818366
# bpd (running average): 2.087330828578068
# bpd (running average): 2.0865518904367675
# bpd (running average): 2.0838694619248352
# bpd (running average): 2.0838247215438996
# bpd (running average): 2.0848778780271835
# bpd (running average): 2.086529494165466
# bpd (running average): 2.084923895219594
# bpd (running average): 2.083850297382719
# bpd (running average): 2.0848775160082056
# bpd (running average): 2.082993951396178
# bpd (running average): 2.086107820727987
# bpd (running average): 2.0852797686037685
# bpd (running average): 2.0857330578236524
# bpd (running average): 2.084554360974551
# bpd (running average): 2.084448485678302
# bpd (running average): 2.0834384059827333
# bpd (running average): 2.0849528427713264
# bpd (running average): 2.0854314656198443
# bpd (running average): 2.084245139791606
# bpd (running average): 2.085525190637627
# bpd (running average): 2.0831313041480204
# bpd (running average): 2.0839852549803943
# bpd (running average): 2.0840225926988785
# bpd (running average): 2.0837845262944934
# bpd (running average): 2.0836857350076214
# bpd (running average): 2.083783842671745
# bpd (running average): 2.0827269556945245
# bpd (running average): 2.0823963893256754
# bpd (running average): 2.082131918825279
# bpd (running average): 2.0821101851671187
# bpd (running average): 2.083187791543638
# bpd (running average): 2.0828958381590366
# bpd (running average): 2.0815877497313484
# bpd (running average): 2.0821151353969674
# bpd (running average): 2.081726346572872
# bpd (running average): 2.0815303792652937
# bpd (running average): 2.083207442098722
# bpd (running average): 2.0840975518965688
# bpd (running average): 2.0836325987082644
# bpd (running average): 2.084127233587749
# bpd (running average): 2.0846638944022255
# bpd (running average): 2.08554528712294
# bpd (running average): 2.0848892917934934
# bpd (running average): 2.085988320216818
# bpd (running average): 2.0866969135779176
# bpd (running average): 2.0866335301249896
# bpd (running average): 2.0858047622784195
# bpd (running average): 2.085443193037094
# bpd (running average): 2.084429477353865
# bpd (running average): 2.084425049608276
# bpd (running average): 2.083721472374168
# bpd (running average): 2.0848856147483503
# bpd (running average): 2.0845308044067465
# bpd (running average): 2.083767220882629
# bpd (running average): 2.0833260805962883
# bpd (running average): 2.0834866699360544
# bpd (running average): 2.082996248889622
# bpd (running average): 2.082524802319705
# bpd (running average): 2.0828012392960966
# bpd (running average): 2.083895768882216
# bpd (running average): 2.0858178607900775
# bpd (running average): 2.0855501149418982
# bpd (running average): 2.085526917685129
# bpd (running average): 2.0848904917422564
# bpd (running average): 2.085123985620368
# bpd (running average): 2.083886946917746
# bpd (running average): 2.083701411560378
# bpd (running average): 2.0854137435854225
# bpd (running average): 2.085101276537637
# bpd (running average): 2.085215034087308
# bpd (running average): 2.0858148853673537
# bpd (running average): 2.085434608796261
# bpd (running average): 2.087288309904617
# bpd (running average): 2.085831800211681
# bpd (running average): 2.0849721974303432
# bpd (running average): 2.0869819303269996
# bpd (running average): 2.0863160752656875
# bpd (running average): 2.0868100343045572
# bpd (running average): 2.086969202208432
# bpd (running average): 2.0880318366524198
# bpd (running average): 2.088934594379628
# bpd (running average): 2.0887917099609137
# bpd (running average): 2.0887097514951476
# bpd (running average): 2.0874892611796843
# bpd (running average): 2.087691996079058
# bpd (running average): 2.088526380033409
# bpd (running average): 2.088892416082767
# bpd (running average): 2.089161133456994
# bpd (running average): 2.0898586538232515
# bpd (running average): 2.0900632254706557
# bpd (running average): 2.090089205962811
# bpd (running average): 2.089015412026829
# bpd (running average): 2.0889477451480754
# bpd (running average): 2.0901978154415577
# bpd (running average): 2.0888705709271544
# bpd (running average): 2.089144748527759
# bpd (running average): 2.089627129815417
# bpd (running average): 2.0902400881406127
# bpd (running average): 2.091510619709292
# bpd (running average): 2.0910586041563874
# bpd (running average): 2.0909726621726414
# bpd (running average): 2.091634965597567
# bpd (running average): 2.091846974830211
# bpd (running average): 2.0925186489035346
# bpd (running average): 2.0941855028124623
# bpd (running average): 2.095247975446748
# bpd (running average): 2.095399617948872
# bpd (running average): 2.096768761375413
# bpd (running average): 2.0956984930727827
# bpd (running average): 2.0953303949200426
# bpd (running average): 2.095374900803077
# bpd (running average): 2.096244334086923
# bpd (running average): 2.0961187218786783
# bpd (running average): 2.0961301221829114
# bpd (running average): 2.0956741020911087
# bpd (running average): 2.0964881348635753
# bpd (running average): 2.095486432146975
# bpd (running average): 2.0947934648098694
# bpd (running average): 2.095447308366351
# bpd (running average): 2.0946873558598873
# bpd (running average): 2.0926758550642415
# bpd (running average): 2.0923667042748173
# bpd (running average): 2.0933024994063865
# bpd (running average): 2.0917371812224403
# bpd (running average): 2.0908543852160215
# bpd (running average): 2.090932895568662
# bpd (running average): 2.0906639764465633
# bpd (running average): 2.090557269504018
# bpd (running average): 2.0907190779763742
# bpd (running average): 2.0903196444289414
# bpd (running average): 2.0900985327121533
# bpd (running average): 2.089580702450245
# bpd (running average): 2.089063439316965
# bpd (running average): 2.088280600508666
# bpd (running average): 2.089251824606575
# bpd (running average): 2.0895574646403636
# bpd (running average): 2.088981968425113
# bpd (running average): 2.0877871869222475
# bpd (running average): 2.0876779866962596
# bpd (running average): 2.0866503746876885
# bpd (running average): 2.086829364344569
# bpd (running average): 2.0881853487071584
# bpd (running average): 2.0886235383183296
# bpd (running average): 2.0888546528475973
# bpd (running average): 2.0898693733968323
# bpd (running average): 2.0898985623425643
# bpd (running average): 2.0893320515548766
# bpd (running average): 2.08901973888698
# bpd (running average): 2.0890571451334896
# bpd (running average): 2.089068942109853
# bpd (running average): 2.088891971198795
# bpd (running average): 2.088680978581895
# bpd (running average): 2.0886545639358913
# bpd (running average): 2.0871898863623493
# bpd (running average): 2.0870741831238036
# bpd (running average): 2.087660388748381
# bpd (running average): 2.088354593945362
# bpd (running average): 2.0891981139921594
# bpd (running average): 2.0885998643884425
# bpd (running average): 2.089199891579222
# bpd (running average): 2.088684378482843
# bpd (running average): 2.088724560097153
# bpd (running average): 2.0884826647118024
# bpd (running average): 2.088678146724022
# bpd (running average): 2.0891140554032117
# bpd (running average): 2.089125751222381
# bpd (running average): 2.089292207800418
# bpd (running average): 2.0898122771388907
# bpd (running average): 2.08993957532307
# bpd (running average): 2.089459610083799
# bpd (running average): 2.0899440462775174
# bpd (running average): 2.0899918318263584
# bpd (running average): 2.090706669018436
# bpd (running average): 2.0904718718292687
# bpd (running average): 2.0908608017863153
# bpd (running average): 2.0900436806265215
# bpd (running average): 2.0902686443113447
# bpd (running average): 2.0909644896814337
# bpd (running average): 2.0903508172707785
# bpd (running average): 2.091243295425308
# bpd (running average): 2.0917298734535805
# bpd (running average): 2.0920222006430684
# bpd (running average): 2.092305840266446
# bpd (running average): 2.092942626715095
# bpd (running average): 2.0927900660536096
# bpd (running average): 2.092967472127425
# bpd (running average): 2.0935807231709314
# bpd (running average): 2.093024058846084
# bpd (running average): 2.092963163594492
# bpd (running average): 2.0932278754384717
# bpd (running average): 2.0931834223738077
# bpd (running average): 2.0936015692315446
# bpd (running average): 2.092915779327659
# bpd (running average): 2.0935247369564634
# bpd (running average): 2.0938592742308315
# bpd (running average): 2.0935019338537724
# bpd (running average): 2.0935515446400697
# bpd (running average): 2.0942619699184615
# bpd (running average): 2.094162966629709
# bpd (running average): 2.0939466642511224
# bpd (running average): 2.094033360219215
# bpd (running average): 2.0941496044638552
# bpd (running average): 2.0933890900086713
# bpd (running average): 2.093257516315171
# bpd (running average): 2.0933881868150293
# bpd (running average): 2.0934014209472713
# bpd (running average): 2.0927223782824806
# bpd (running average): 2.093205871186191
# bpd (running average): 2.0928795520433465
# bpd (running average): 2.0924405134074107
# bpd (running average): 2.0922430926207753
# bpd (running average): 2.0926325416991025
# bpd (running average): 2.0922762496421385
# bpd (running average): 2.0921262456645713
# bpd (running average): 2.092970120180562
# bpd (running average): 2.09251794183986
# bpd (running average): 2.092151180399485
# bpd (running average): 2.092607360341675
# bpd (running average): 2.0921622458704143
# bpd (running average): 2.0933161290689535
# bpd (running average): 2.0929044423033547
# bpd (running average): 2.09322176933851
# bpd (running average): 2.092812584352592
# bpd (running average): 2.092175591656369
# bpd (running average): 2.092808953951133
# bpd (running average): 2.0927467700224622
# bpd (running average): 2.0919823535279
# bpd (running average): 2.0919629968961178
# bpd (running average): 2.092477147444132
# bpd (running average): 2.092315265923653
# bpd (running average): 2.091424018875259
# bpd (running average): 2.0913659269320464
# bpd (running average): 2.090651753205653
# bpd (running average): 2.090947013555802
# bpd (running average): 2.0905409592278312
# bpd (running average): 2.0905719432372663
# bpd (running average): 2.09093999632471
# bpd (running average): 2.0904652141708615
# bpd (running average): 2.0904368471246406
# bpd (running average): 2.0908509488430203
# bpd (running average): 2.090772280879571
# bpd (running average): 2.0905529888618135
# bpd (running average): 2.09033312167387
# bpd (running average): 2.091027800997026
# bpd (running average): 2.09092081505326
# bpd (running average): 2.0912480839947936
# bpd (running average): 2.090991287573122
# bpd (running average): 2.092312050822949
# bpd (running average): 2.09273973105607
# bpd (running average): 2.0926267960744505
# bpd (running average): 2.0924933421092686
# bpd (running average): 2.09264870407549
# bpd (running average): 2.093861383531764
# bpd (running average): 2.094415269839287
# bpd (running average): 2.094666855650812
# bpd (running average): 2.0948596223843308
# bpd (running average): 2.094364513043149
# bpd (running average): 2.0944814152026274
# bpd (running average): 2.09430582966921
# bpd (running average): 2.094327346119168
# bpd (running average): 2.095325680527369
# bpd (running average): 2.0956747116585044
# bpd (running average): 2.0962517416930617
# bpd (running average): 2.096339282037113
# bpd (running average): 2.0967322896299776
# bpd (running average): 2.096203397446653
# bpd (running average): 2.096156612441034
# bpd (running average): 2.095955688526686
# bpd (running average): 2.0959964010482337
# bpd (running average): 2.095875077911324
# bpd (running average): 2.0961529171248374
# bpd (running average): 2.0964623273857774
# bpd (running average): 2.096770387905074
# bpd (running average): 2.0968650086373986
# bpd (running average): 2.0971214477120768
# bpd (running average): 2.09664139141665
# bpd (running average): 2.0966026773874407
# bpd (running average): 2.09621461766718
# bpd (running average): 2.0964788716708695
# bpd (running average): 2.095840383326476
# bpd (running average): 2.0964153808157433
# bpd (running average): 2.096465705307799
# bpd (running average): 2.095466718510674
# bpd (running average): 2.095011420708752
# bpd (running average): 2.095965946288892
# bpd (running average): 2.0961508988538893
# bpd (running average): 2.0957821159793975
# bpd (running average): 2.095352009451246
# bpd (running average): 2.095710740076651
# bpd (running average): 2.095275050017626
# bpd (running average): 2.0952701460907903
# bpd (running average): 2.0950470516236988
# bpd (running average): 2.094555087448033
# bpd (running average): 2.0944753395345814
# bpd (running average): 2.094212956337882
# bpd (running average): 2.094311972799198
# bpd (running average): 2.094809467033605
# bpd (running average): 2.0948130288404845
# bpd (running average): 2.094691833832175
# bpd (running average): 2.0947110988462865
# bpd (running average): 2.0941429836367473
# bpd (running average): 2.093919420885791
# bpd (running average): 2.0937545299647105
# bpd (running average): 2.0933721068513087
# bpd (running average): 2.0941632555608303
# bpd (running average): 2.094522959390862
# bpd (running average): 2.09445913190592
# bpd (running average): 2.094166115023057
# bpd (running average): 2.094048992053775
# bpd (running average): 2.094314074916257
# bpd (running average): 2.0941175878441887
# bpd (running average): 2.0936065577001703
# bpd (running average): 2.0933392160849134
# bpd (running average): 2.0932420346208596
# bpd (running average): 2.0934167985950385
# bpd (running average): 2.092989386414285
# bpd (running average): 2.0930849461502787
# bpd (running average): 2.093505439870867
# bpd (running average): 2.093034665672614
# bpd (running average): 2.0931612967973185
# bpd (running average): 2.0927580558264363
# bpd (running average): 2.092363852297018
# bpd (running average): 2.092845420883784
# bpd (running average): 2.0928062951489563
# bpd (running average): 2.0930156084577685
# bpd (running average): 2.0929639587510183
# bpd (running average): 2.092707269442619
# bpd (running average): 2.092572211399187
# bpd (running average): 2.092461194617645
# bpd (running average): 2.092603324560273
# bpd (running average): 2.0928944751904606
# bpd (running average): 2.093004214153283
# bpd (running average): 2.093126719684714
# bpd (running average): 2.092704817847742
# bpd (running average): 2.092757759372456
# bpd (running average): 2.0927499543972248
# bpd (running average): 2.092635996717152
# bpd (running average): 2.0927388919346104
# bpd (running average): 2.092280484804805
# bpd (running average): 2.092448556580809
# bpd (running average): 2.0927123544741857
# bpd (running average): 2.0925655610084863
# bpd (running average): 2.0930714288275287
# bpd (running average): 2.0936316412248743
# bpd (running average): 2.0933126794548347
# bpd (running average): 2.093916661054208
# bpd (running average): 2.0939801247622727
# bpd (running average): 2.0941857680219234
# bpd (running average): 2.094056254618385
# bpd (running average): 2.094530833074562
# bpd (running average): 2.09466830990375
# bpd (running average): 2.0940987988528064
# bpd (running average): 2.093692932338603
# bpd (running average): 2.0936433817508924
# bpd (running average): 2.093075273085499
# bpd (running average): 2.093320411060683
# bpd (running average): 2.093420653640245
# bpd (running average): 2.093046311288781
# bpd (running average): 2.0928701263963982
# bpd (running average): 2.092832305459405
# bpd (running average): 2.0927370940943333
# bpd (running average): 2.0926474310379763
# bpd (running average): 2.0925965457885316
# bpd (running average): 2.0922390115544083
# bpd (running average): 2.0922120636987938
# bpd (running average): 2.092129715872564
# bpd (running average): 2.092232254239473
# bpd (running average): 2.0929402911184374
# bpd (running average): 2.0928982672786356
# bpd (running average): 2.0924988083320106
# bpd (running average): 2.0924649495278196
# bpd (running average): 2.0923496780232265
# bpd (running average): 2.092569532070176
# bpd (running average): 2.0927956910514163
# bpd (running average): 2.0928692587610183
# bpd (running average): 2.0928797555198604
# bpd (running average): 2.0928651973786616
# bpd (running average): 2.092365391409626
# bpd (running average): 2.092313571026857
# bpd (running average): 2.0929154165402397
# bpd (running average): 2.0925463046811266
# bpd (running average): 2.092071743627764
# bpd (running average): 2.091553335383151
# bpd (running average): 2.091718599815281
# bpd (running average): 2.0914287651841605
# bpd (running average): 2.091302758216841
# bpd (running average): 2.091267781571847
# bpd (running average): 2.0912023610571926
# bpd (running average): 2.0912909918125715
# bpd (running average): 2.0911322838402926
# bpd (running average): 2.0914603557935494
# bpd (running average): 2.091635108257101
# bpd (running average): 2.0919036501663397
# bpd (running average): 2.0917441995031805
# bpd (running average): 2.0916538816221295
# bpd (running average): 2.091899163520001
# bpd (running average): 2.091788868395172
# bpd (running average): 2.091740538772124
# bpd (running average): 2.091477683868872
# bpd (running average): 2.0910823368100484
# bpd (running average): 2.0911294788476233
# bpd (running average): 2.0907687798835743
# bpd (running average): 2.0908179388699963
# bpd (running average): 2.0907454829191527
# bpd (running average): 2.0907894358522436
# bpd (running average): 2.0912195963643976
# bpd (running average): 2.091381020636904
# bpd (running average): 2.090879790184992
# bpd (running average): 2.0910024317305163
# bpd (running average): 2.090922796156682
# bpd (running average): 2.090532649225322
# bpd (running average): 2.0900830716970034
# bpd (running average): 2.090954780536826
# bpd (running average): 2.091411195877062
# bpd (running average): 2.091512704374566
# bpd (running average): 2.091809828650474
# bpd (running average): 2.091985473049967
# bpd (running average): 2.092016670807159
# bpd (running average): 2.0916469523278165
# bpd (running average): 2.0913125208777554
# bpd (running average): 2.091448455714008
# bpd (running average): 2.0910896096238614
# bpd (running average): 2.0909916115167255
# bpd (running average): 2.0910365351124147
# bpd (running average): 2.090952296851841
# bpd (running average): 2.090607519918755
# bpd (running average): 2.0911587725470056
# bpd (running average): 2.091001154506767
# bpd (running average): 2.091210933453358
# bpd (running average): 2.0909495780776433
# bpd (running average): 2.0910814336401207
# bpd (running average): 2.0908179280496038
# bpd (running average): 2.090978760605195
# bpd (running average): 2.0906003961446227
# bpd (running average): 2.0909211820218494
# bpd (running average): 2.0908712428224985
# bpd (running average): 2.090938637060752
# bpd (running average): 2.0907119481493357
# bpd (running average): 2.0907124327773308
# bpd (running average): 2.0902600666146243
# bpd (running average): 2.090160263231285
# bpd (running average): 2.090010540492588
# bpd (running average): 2.089907997506275
# bpd (running average): 2.0897574904303813
# bpd (running average): 2.08930933751991
# bpd (running average): 2.0896757981169687
# bpd (running average): 2.089613019082231
# bpd (running average): 2.08937732949801
# bpd (running average): 2.089883689599875
# bpd (running average): 2.090106902364461
# bpd (running average): 2.089969006365078
# bpd (running average): 2.0900926144244094
# bpd (running average): 2.0906413508718953
# bpd (running average): 2.090390262298388
# bpd (running average): 2.0905315754841904
# bpd (running average): 2.0906949373818873
# bpd (running average): 2.090935928064299
# bpd (running average): 2.091137308413103
# bpd (running average): 2.091265116754721
# bpd (running average): 2.0910035624380723
# bpd (running average): 2.09125026812553
# bpd (running average): 2.0914605504140193
# bpd (running average): 2.0917833868211395
# bpd (running average): 2.091731865593277
# bpd (running average): 2.091923405882943
# bpd (running average): 2.0916792598641587
# bpd (running average): 2.0920515801003843
# bpd (running average): 2.091811119497572
# bpd (running average): 2.09221113144818
# bpd (running average): 2.0918456130350065
# bpd (running average): 2.091933744972008
# bpd (running average): 2.091802558235673
# bpd (running average): 2.0919705954084984
# bpd (running average): 2.091961316286564
# bpd (running average): 2.0919790371296885
# bpd (running average): 2.091918125980645
# bpd (running average): 2.091959618887872
# bpd (running average): 2.091848731209515
# bpd (running average): 2.091585937891243
# bpd (running average): 2.0914671660798567
# bpd (running average): 2.0916335757728084
# bpd (running average): 2.0914903675523853
# bpd (running average): 2.091524131194668
# bpd (running average): 2.091129302879774
# bpd (running average): 2.091128495156475
# bpd (running average): 2.0906924306675227
# bpd (running average): 2.0911299256088087
# bpd (running average): 2.091134977688745
# bpd (running average): 2.090837012763283
# bpd (running average): 2.0905427191490764
# bpd (running average): 2.090890582292973
# bpd (running average): 2.0909124802721823
# bpd (running average): 2.0910663674034966
# bpd (running average): 2.0910353831351336
# bpd (running average): 2.0910366926360187
# bpd (running average): 2.09127308335653
# bpd (running average): 2.0912788862019367
# bpd (running average): 2.0909884990077123
# bpd (running average): 2.090827146576827
# bpd (running average): 2.090815115675619
# bpd (running average): 2.091107471742982
# bpd (running average): 2.091016586875241
# bpd (running average): 2.0908648251059203
# bpd (running average): 2.090664548539561
# bpd (running average): 2.0904852507972396
# bpd (running average): 2.0904665460591088
# bpd (running average): 2.0909931464091693
# bpd (running average): 2.091223709179305
# bpd (running average): 2.0908470866346964
# bpd (running average): 2.0906585158621085
# bpd (running average): 2.090695259794204
# bpd (running average): 2.0909925314591797
# bpd (running average): 2.0910406723586124
# bpd (running average): 2.0909743547658013
# bpd (running average): 2.0911100720436924
# bpd (running average): 2.0909293264213034
# bpd (running average): 2.091237140315607
# bpd (running average): 2.091106026097108
# bpd (running average): 2.0914647091214995
# bpd (running average): 2.0916510201429936
# bpd (running average): 2.0918067303209145
# bpd (running average): 2.092122311073429
# bpd (running average): 2.092156328441564
# bpd (running average): 2.091996309426059
# bpd (running average): 2.091608477972193
# bpd (running average): 2.0915603491471457
# bpd (running average): 2.0912060227815736
# bpd (running average): 2.0914583354497185
# bpd (running average): 2.091612669176855
# bpd (running average): 2.091315792426346
# bpd (running average): 2.091451837634348
# bpd (running average): 2.091147344888632
# bpd (running average): 2.09147117120083
# bpd (running average): 2.091292982703188
# bpd (running average): 2.0915006960436577
# bpd (running average): 2.0916326519086956
# bpd (running average): 2.0918340036628864
# bpd (running average): 2.091741980989572
# bpd (running average): 2.09186340874507
# bpd (running average): 2.0922414715360844
# bpd (running average): 2.0921046430158117
# bpd (running average): 2.091752077184281
# bpd (running average): 2.0915620380903093
# bpd (running average): 2.0915275542821896
# bpd (running average): 2.092011193922689
# bpd (running average): 2.092051495972763
# bpd (running average): 2.091846208027916
# bpd (running average): 2.0917872622300817
# bpd (running average): 2.091543716294934
# bpd (running average): 2.0915838796562736
# bpd (running average): 2.091884081559131
# bpd (running average): 2.0919313292096144
# bpd (running average): 2.0917889843411
# bpd (running average): 2.091696982415195
# bpd (running average): 2.0917418646805346
# bpd (running average): 2.0918189951415784
# bpd (running average): 2.0919832576004516
# bpd (running average): 2.091977213969285
# bpd (running average): 2.0919117796050464
# bpd (running average): 2.091988376147768
# bpd (running average): 2.0916859808579096
# bpd (running average): 2.0913371170532287
# bpd (running average): 2.0912560833709044
# bpd (running average): 2.0914541020222
# bpd (running average): 2.091614421230414
# bpd (running average): 2.091435177080847
# bpd (running average): 2.091312150057414
# bpd (running average): 2.091635999705329
# bpd (running average): 2.0916774723107534
# bpd (running average): 2.0918603484547535
# bpd (running average): 2.0916998400050244
# bpd (running average): 2.0916842193242493
# bpd (running average): 2.0915340915102227
# bpd (running average): 2.091365310100323
# bpd (running average): 2.091500891422085
# bpd (running average): 2.0908776008404972
# bpd (running average): 2.0907754683084354
# bpd (running average): 2.0907628096940987
# bpd (running average): 2.090361591950186
# bpd (running average): 2.090381067585005
# bpd (running average): 2.090168665647614
# bpd (running average): 2.0902235806423772
# bpd (running average): 2.0900886331639503
# bpd (running average): 2.0902128350138662
# bpd (running average): 2.0898270174171385
# bpd (running average): 2.089955248498935
# bpd (running average): 2.0901297763168025
# bpd (running average): 2.0897624399677417
# bpd (running average): 2.0900177419885386
# bpd (running average): 2.090163533706641
# bpd (running average): 2.090257598934223
# bpd (running average): 2.0903268136199427
# bpd (running average): 2.090415402711952
# bpd (running average): 2.09040376797275
# bpd (running average): 2.090813106923789
# bpd (running average): 2.091009819480391
# bpd (running average): 2.0908268870667372
# bpd (running average): 2.0905953301191564
# bpd (running average): 2.090501647046389
# bpd (running average): 2.0903244891608823
# bpd (running average): 2.0907968522307128
# bpd (running average): 2.091110491853104
# bpd (running average): 2.091381841887793
# bpd (running average): 2.091443020495301
# bpd (running average): 2.0914033426379475
# bpd (running average): 2.09136806491933
# bpd (running average): 2.091270775852481
# bpd (running average): 2.091492507384543
# bpd (running average): 2.091274452515196
# bpd (running average): 2.0911051266580123
# bpd (running average): 2.091406221639627
# bpd (running average): 2.091182109671218
# bpd (running average): 2.091085752705256
# bpd (running average): 2.091072015385903
# bpd (running average): 2.09126737881736
# bpd (running average): 2.0912246187018475
# bpd (running average): 2.0914756028219115
# bpd (running average): 2.0913921860015243
# bpd (running average): 2.0911716559133717
# bpd (running average): 2.091295157209368
# bpd (running average): 2.0911185789299216
# bpd (running average): 2.09105996887408
# bpd (running average): 2.090859466409804
# bpd (running average): 2.09135044990218
# bpd (running average): 2.0913798253710256
# bpd (running average): 2.091416843927435
# bpd (running average): 2.0916159333027644
# bpd (running average): 2.0914056627818676
# bpd (running average): 2.0912979741801383
# bpd (running average): 2.091151738972731
# bpd (running average): 2.0912985634900787
# bpd (running average): 2.0911604420687846
# bpd (running average): 2.0911089470866955
# bpd (running average): 2.0911731463718044
# bpd (running average): 2.091178237486387
# bpd (running average): 2.091245929231972
# bpd (running average): 2.090984134612648
# bpd (running average): 2.0906844770371498
# bpd (running average): 2.0906100200684334
# bpd (running average): 2.090461697340149
# bpd (running average): 2.0907696938366724
# bpd (running average): 2.090540230999343
# bpd (running average): 2.0906087438285237
# bpd (running average): 2.090267681878064
# bpd (running average): 2.090272618607797
# bpd (running average): 2.0902301206468517
# bpd (running average): 2.090378096008006
# bpd (running average): 2.090618422479765
# bpd (running average): 2.090919420399262
# bpd (running average): 2.0909688229445154
# bpd (running average): 2.090841089411511
# bpd (running average): 2.0908831962731953
# bpd (running average): 2.0908090019208374
# bpd (running average): 2.090757711701864
# bpd (running average): 2.0908037596316134
# bpd (running average): 2.0911711583269326
# bpd (running average): 2.0909189140918953
# bpd (running average): 2.091015995642047
# bpd (running average): 2.090854563919606
# bpd (running average): 2.090786181503891
# bpd (running average): 2.090727970427503
# bpd (running average): 2.090609665492293
# bpd (running average): 2.0905583250779816
# bpd (running average): 2.0905229512863452
# bpd (running average): 2.0903221325345336
# bpd (running average): 2.0902155817735215
# bpd (running average): 2.0901473330758766
# bpd (running average): 2.0901698955168033
# bpd (running average): 2.090131029105258
# bpd (running average): 2.0903285410421173
# bpd (running average): 2.0901821687603626
# bpd (running average): 2.0899768104609406
# bpd (running average): 2.089585661575753
# bpd (running average): 2.0895704126730417
# bpd (running average): 2.089590324021519
# bpd (running average): 2.089523315291034
# bpd (running average): 2.089452200494885
# bpd (running average): 2.0896493594229373
# bpd (running average): 2.0896776375016244
# bpd (running average): 2.0900719562605286
# bpd (running average): 2.089797748780687
# bpd (running average): 2.0897612716688
# bpd (running average): 2.0896503915617415
# bpd (running average): 2.0899248281349365
# bpd (running average): 2.089880168699845
# bpd (running average): 2.0899321859807234
# bpd (running average): 2.0901413107237135
# bpd (running average): 2.0901652969255653
# bpd (running average): 2.090216539190792
# bpd (running average): 2.0901274592687273
# bpd (running average): 2.090203885277704
# bpd (running average): 2.0903828103519593
# bpd (running average): 2.090270283809567
# bpd (running average): 2.089970844404735
# bpd (running average): 2.0899846744654695
# bpd (running average): 2.0899356102981113
# bpd (running average): 2.0903082168149503
# bpd (running average): 2.090304619554039
# bpd (running average): 2.089744442347363
# bpd (running average): 2.089608807092844
# bpd (running average): 2.0893800744263173
# bpd (running average): 2.0890759513351367
# bpd (running average): 2.0893064745833123
# bpd (running average): 2.089496107643646
# bpd (running average): 2.0891435397700584
# bpd (running average): 2.0893026753993347
# bpd (running average): 2.0893654962619417
# bpd (running average): 2.0890943319750455
# bpd (running average): 2.0891699489844067
# bpd (running average): 2.089053193624128
# bpd (running average): 2.088912938021344
# bpd (running average): 2.088890447998104
# bpd (running average): 2.08863018609255
# bpd (running average): 2.089024627525884
# bpd (running average): 2.088736065173462
# bpd (running average): 2.088891220000427
# bpd (running average): 2.0889960001591428
# bpd (running average): 2.0890911866783957
# bpd (running average): 2.0892427255312787
# bpd (running average): 2.089260973673749
# bpd (running average): 2.089365323570845
# bpd (running average): 2.0894046768354197
# bpd (running average): 2.089542064325362
# bpd (running average): 2.089870610058743
# bpd (running average): 2.0896519209205957
# bpd (running average): 2.0895392894966838
# bpd (running average): 2.0894160812045226
# bpd (running average): 2.0891774161157888
# bpd (running average): 2.0893761201760466
# bpd (running average): 2.089519164733311
# bpd (running average): 2.0895801524365116
# bpd (running average): 2.089681177399355
# bpd (running average): 2.089828135362799
# bpd (running average): 2.0900773582076506
# bpd (running average): 2.090237337909843
# bpd (running average): 2.0904109321569733
# bpd (running average): 2.090541335040378
# bpd (running average): 2.0904296166739935
# bpd (running average): 2.090595309936739
# bpd (running average): 2.090766281003069
# bpd (running average): 2.090723491152112
# bpd (running average): 2.090806227006563
# bpd (running average): 2.090843528010452
# bpd (running average): 2.0908495658030892
# bpd (running average): 2.090756161252123
# bpd (running average): 2.0909052856556807
# bpd (running average): 2.0910565351724877
# bpd (running average): 2.0910004293724676
# bpd (running average): 2.0909578301568246
# bpd (running average): 2.0910021255778224
# bpd (running average): 2.0910469750221896
# bpd (running average): 2.0912587787472843
# bpd (running average): 2.0913696863400157
# bpd (running average): 2.091256914500213
# bpd (running average): 2.0913455934997787
# bpd (running average): 2.0912185672437498
# bpd (running average): 2.0912139210214375
# bpd (running average): 2.0912231180635157
# bpd (running average): 2.0910753328853002
# bpd (running average): 2.0908764323411204
# bpd (running average): 2.090992695275873
# bpd (running average): 2.0909808490031114
# bpd (running average): 2.0910095817584153
# bpd (running average): 2.0912327532461052
# bpd (running average): 2.091005513767402
# bpd (running average): 2.090892064013514
# bpd (running average): 2.0907602567565626
# bpd (running average): 2.09052175942924
# bpd (running average): 2.0904316406591144
# bpd (running average): 2.090422845966196
# bpd (running average): 2.090457448303477
# bpd (running average): 2.090404416156044
# bpd (running average): 2.090596967106651
# bpd (running average): 2.0907098136190645
# bpd (running average): 2.090970423529456
# bpd (running average): 2.091114424684971
# bpd (running average): 2.0912263059413703
# bpd (running average): 2.091239482609451
# bpd (running average): 2.0913813334813534
# bpd (running average): 2.0914408411606447
# bpd (running average): 2.091206441628009
# bpd (running average): 2.091153188360401
# bpd (running average): 2.091247150454679
# bpd (running average): 2.0912515608555493
# bpd (running average): 2.0914027319062187
# bpd (running average): 2.0916982280674206
# bpd (running average): 2.0917579885291184
# bpd (running average): 2.0918546555335373
# bpd (running average): 2.091883841793972
# bpd (running average): 2.0918817882355403
# bpd (running average): 2.091949894496358
# bpd (running average): 2.091879903595589
# bpd (running average): 2.091566962789893
# bpd (running average): 2.091618002818386
# bpd (running average): 2.09166850822224
# bpd (running average): 2.091671115170547
# bpd (running average): 2.091608052153469
# bpd (running average): 2.091805261360704
# bpd (running average): 2.0918937006425544
# bpd (running average): 2.0918529132959356
# bpd (running average): 2.0920714126036404
# bpd (running average): 2.092331148373863
# bpd (running average): 2.092451284029893
# bpd (running average): 2.0924465506684973
# bpd (running average): 2.092434879065119
# bpd (running average): 2.092462549776443
# bpd (running average): 2.0924781170858724
# bpd (running average): 2.0928908342937684
# bpd (running average): 2.092895693533338
# bpd (running average): 2.092659067237355
# bpd (running average): 2.092540358940363
# bpd (running average): 2.092288135475707
# bpd (running average): 2.0922423358748636
# bpd (running average): 2.0922439313348726
# bpd (running average): 2.0920151487781937
# bpd (running average): 2.091802227071526
# bpd (running average): 2.091895894459304
# bpd (running average): 2.091989352902151
# bpd (running average): 2.091768788823274
# bpd (running average): 2.0916101822344952
# bpd (running average): 2.0915865978164097
# bpd (running average): 2.091567288964272
# bpd (running average): 2.091365725572242
# bpd (running average): 2.091451524605731
# bpd (running average): 2.091555224439998
# bpd (running average): 2.0915185305679533
# bpd (running average): 2.091442624433853
# bpd (running average): 2.091324565273442
# bpd (running average): 2.091388923532968
# bpd (running average): 2.091367048452872
# bpd (running average): 2.091201188055106
# bpd (running average): 2.0911316975845593
# bpd (running average): 2.091130032963096
# bpd (running average): 2.090965968634803
# bpd (running average): 2.0910029118952975
# bpd (running average): 2.0910575684474293
# bpd (running average): 2.0909568901405384
# bpd (running average): 2.0908346985178228
# bpd (running average): 2.0906610607001785
# bpd (running average): 2.0906260350102386
# bpd (running average): 2.0906753954114077
# bpd (running average): 2.090741603804723
# bpd (running average): 2.0904571981631417
# bpd (running average): 2.0902974699853076
# bpd (running average): 2.090321936676939
# bpd (running average): 2.0901915851885144
# bpd (running average): 2.0902015014649256
# bpd (running average): 2.0900163850370026
# bpd (running average): 2.089971630982693
# bpd (running average): 2.0899955019156753
# bpd (running average): 2.089994225462806
# bpd (running average): 2.0901269333408603
# bpd (running average): 2.0901029650804057
# bpd (running average): 2.0900314014890777
# bpd (running average): 2.090326620614174
# bpd (running average): 2.0902376850219837
# bpd (running average): 2.0903851305353798
# bpd (running average): 2.0905585705803804
# bpd (running average): 2.090498804400612
# bpd (running average): 2.0904710428490554
# bpd (running average): 2.0906848846138875
# bpd (running average): 2.0905262913098395
# bpd (running average): 2.0905298854746768
# bpd (running average): 2.090383413349831
# bpd (running average): 2.090337303123735
# bpd (running average): 2.0902693417009477
# bpd (running average): 2.090353156805125
# bpd (running average): 2.090258748291995
# bpd (running average): 2.090168452770628
# bpd (running average): 2.0901910344646772
# bpd (running average): 2.0901988864119523
# bpd (running average): 2.0902653254931587
# bpd (running average): 2.0903152258236726
# bpd (running average): 2.090448382497285
# bpd (running average): 2.090599980104674
# bpd (running average): 2.090417280748219
# bpd (running average): 2.090449606016956
# bpd (running average): 2.0904249404366833
# bpd (running average): 2.090462748003733
# bpd (running average): 2.0906396392709214
# bpd (running average): 2.0906454901286247
# bpd (running average): 2.0905133018810753
# bpd (running average): 2.090682495698854
# bpd (running average): 2.090610666652724
# bpd (running average): 2.090463607692108
# bpd (running average): 2.0903708039826348
# bpd (running average): 2.090412838584597
# bpd (running average): 2.090418469509146
# bpd (running average): 2.090521303049527
# bpd (running average): 2.090670069916835
# bpd (running average): 2.090589536766197
# bpd (running average): 2.090729910039454
# bpd (running average): 2.0906803066145687
# bpd (running average): 2.0907882613905633
# bpd (running average): 2.0908659602447175
# bpd (running average): 2.0908857197317685
# bpd (running average): 2.090599740900389
# bpd (running average): 2.0906523302974653
# bpd (running average): 2.0903711477343263
# bpd (running average): 2.0904669709470314
# bpd (running average): 2.090446531351899
# bpd (running average): 2.0907237397148077
# bpd (running average): 2.0910471735733065
# bpd (running average): 2.0909356838775515
# bpd (running average): 2.0909259062441223
# bpd (running average): 2.090634383365944
# bpd (running average): 2.0905103722971576
# bpd (running average): 2.090562488368026
# bpd (running average): 2.0904867349500744
# bpd (running average): 2.090417298967175
# bpd (running average): 2.090322310320999
# bpd (running average): 2.090510321842579
# bpd (running average): 2.0903495153908924
# bpd (running average): 2.0904426166399146
# bpd (running average): 2.0904428329793334
# bpd (running average): 2.090586104098603
# bpd (running average): 2.0902545693926693
# bpd (running average): 2.090496683498185
# bpd (running average): 2.090592065443119
# bpd (running average): 2.090898343965189
# bpd (running average): 2.09103292241685
# bpd (running average): 2.0909667088140296
# bpd (running average): 2.0908692547907153
# bpd (running average): 2.0909005726215577
# bpd (running average): 2.0910367949203432
# bpd (running average): 2.0909986728089884
# bpd (running average): 2.0908546968499673
# bpd (running average): 2.0908165696962357
# bpd (running average): 2.090671586976398
# bpd (running average): 2.0906048237011805
# bpd (running average): 2.090735833179249
# bpd (running average): 2.0908108638947365
# bpd (running average): 2.090702844110107
# bpd (running average): 2.0906733893020353
# bpd (running average): 2.0909757618414293
# bpd (running average): 2.091195487090565
# bpd (running average): 2.09128226146882
# bpd (running average): 2.0910943903934482
# bpd (running average): 2.0909860553559523
# bpd (running average): 2.0909145391928563
# bpd (running average): 2.090832890145852
# bpd (running average): 2.090954013249099
# bpd (running average): 2.0910324418386503
# bpd (running average): 2.0910528020156494
# bpd (running average): 2.0908985283678763
# bpd (running average): 2.0909184298051695
# bpd (running average): 2.091035825718912
# bpd (running average): 2.0909607576932525
# bpd (running average): 2.0910592051654517
# bpd (running average): 2.090815138848105
# bpd (running average): 2.090987131952807
# bpd (running average): 2.0908302944966635
# bpd (running average): 2.0905412804967574
# bpd (running average): 2.0905067158429795
# bpd (running average): 2.0902898221412385
# bpd (running average): 2.0901552879729826
# bpd (running average): 2.089953948498366
# bpd (running average): 2.0897959577361225
# bpd (running average): 2.0899313586763015
# bpd (running average): 2.089841041580361
# bpd (running average): 2.0898406348323726
# bpd (running average): 2.0894420456182927
# bpd (running average): 2.0894684158896495
# bpd (running average): 2.089526380673768
# bpd (running average): 2.0896219739835473
# bpd (running average): 2.0898591236482322
# bpd (running average): 2.0900445270892414
# bpd (running average): 2.0902834035306084
# bpd (running average): 2.090352892937544
# bpd (running average): 2.090250943902152
# bpd (running average): 2.0902490817791812
# bpd (running average): 2.0900924884440744
# bpd (running average): 2.090020721985916
# bpd (running average): 2.090308809249402
# bpd (running average): 2.09030462021938
# bpd (running average): 2.09059339773149
# bpd (running average): 2.0905747004174486
# bpd (running average): 2.090662643106591
# bpd (running average): 2.0906249981159832
# bpd (running average): 2.0904683843784517
# bpd (running average): 2.0903123332291096
# bpd (running average): 2.0901898406008215
# bpd (running average): 2.0902843491665224
# bpd (running average): 2.090484279151271
# bpd (running average): 2.090447787294163
# bpd (running average): 2.0904978627662327
# bpd (running average): 2.0904727988441727
# bpd (running average): 2.0904300177833757
# bpd (running average): 2.090484906572432
# bpd (running average): 2.090512903701278
# bpd (running average): 2.090615409428694
# bpd (running average): 2.0906557077139913
# bpd (running average): 2.090501863068216
# bpd (running average): 2.090278122704314
# bpd (running average): 2.0903259079307506
# bpd (running average): 2.09016754516712
# bpd (running average): 2.0901129112921955
# bpd (running average): 2.0900700899971243
# bpd (running average): 2.089928163584078
# bpd (running average): 2.0900400677397983
# bpd (running average): 2.0900440293753255
# bpd (running average): 2.0899754015090837
# bpd (running average): 2.0898947263834122
# bpd (running average): 2.08973854659821
# bpd (running average): 2.08949175746318
# bpd (running average): 2.0896082457376703
# bpd (running average): 2.0895910707102874
# bpd (running average): 2.0898284480970513
# bpd (running average): 2.0900327307641167
# bpd (running average): 2.0898974359807987
# bpd (running average): 2.0899480743958723
# bpd (running average): 2.0899263333509994
# bpd (running average): 2.089763247947951
# bpd (running average): 2.089876087030996
# bpd (running average): 2.0899878834921104
# bpd (running average): 2.0899332682637284
# bpd (running average): 2.0900689714174363
# bpd (running average): 2.090184779634539
# bpd (running average): 2.0902499005019153
# bpd (running average): 2.0902740651938063
# bpd (running average): 2.0902871751381342
# bpd (running average): 2.090111910469783
# bpd (running average): 2.090004945769334
# bpd (running average): 2.0899184800499975
# bpd (running average): 2.0899176592935174
# bpd (running average): 2.0899450819397205
# bpd (running average): 2.0899585604086837
# bpd (running average): 2.0900481347197903
# bpd (running average): 2.0901333150034516
# bpd (running average): 2.0901084658105953
# bpd (running average): 2.0901075989062154
# bpd (running average): 2.0900721249210013
# bpd (running average): 2.090013583790922
# bpd (running average): 2.0899111684774616
# bpd (running average): 2.0899081630697616
# bpd (running average): 2.0899065762177025
# bpd (running average): 2.0897769659123075
# bpd (running average): 2.0897312051075225
# bpd (running average): 2.089683749368601
# bpd (running average): 2.0895746273217615
# bpd (running average): 2.0895071426845924
# bpd (running average): 2.089737895467831
# bpd (running average): 2.089785404190208
# bpd (running average): 2.089706362083218
# bpd (running average): 2.0898421252598416
# bpd (running average): 2.089695581250773
# bpd (running average): 2.0897455035888637
# bpd (running average): 2.0897172467991267
# bpd (running average): 2.0896669807437154
# bpd (running average): 2.089656648161139
# bpd (running average): 2.089528208068402
# bpd (running average): 2.08963198049138
# bpd (running average): 2.089579413541326
# bpd (running average): 2.089663639972208
# bpd (running average): 2.0896842652454684
# bpd (running average): 2.089776217503334
# bpd (running average): 2.0898604294024286
# bpd (running average): 2.0898567761852647
# bpd (running average): 2.089961902093066
# bpd (running average): 2.0899909295856207
# bpd (running average): 2.0898817936330576
# bpd (running average): 2.089899822475164
# bpd (running average): 2.090131054188786
# bpd (running average): 2.090136263070251
# bpd (running average): 2.0902206155491774
# bpd (running average): 2.0902442976986197
# bpd (running average): 2.090246593001802
# bpd (running average): 2.0902712940176285
# bpd (running average): 2.0902430241321532
# bpd (running average): 2.0900568612253703
# bpd (running average): 2.090106436384675
# bpd (running average): 2.0903208719048276
# bpd (running average): 2.0902285957853963
# bpd (running average): 2.090116591845846
# ...
# bpd (running average): 2.0890559256611403
# bpd (running average): 2.08898476047369
# bpd (running average): 2.0890887533013127
# bpd (running average): 2.0892412660705255
# bpd (running average): 2.089331645861985
# bpd (running average): 2.089319180787915
# bpd (running average): 2.0892998161471357
# bpd (running average): 2.0894007593966943
# bpd (running average): 2.0892564259983217
# bpd (running average): 2.0893213757094
# bpd (running average): 2.089458813547736
# bpd (running average): 2.0893735774820033
# bpd (running average): 2.0894114915701505
# bpd (running average): 2.08943426379045
# bpd (running average): 2.0893902833801383
# bpd (running average): 2.089559752661645
# bpd (running average): 2.089480711591546
# bpd (running average): 2.0894685119350083
# bpd (running average): 2.0895066704872063
# bpd (running average): 2.0895932624983766
# bpd (running average): 2.0895920840212536
# bpd (running average): 2.089609466524845
# bpd (running average): 2.0895915304901274
# bpd (running average): 2.0896289828844554
# bpd (running average): 2.0896307390096633
# bpd (running average): 2.089701719696072
# bpd (running average): 2.089451032061629
# bpd (running average): 2.0894046184915513
# bpd (running average): 2.089520802777071
# bpd (running average): 2.089618459410789
# bpd (running average): 2.0896495493970035
# bpd (running average): 2.089560629534668
# bpd (running average): 2.089554050919584
# bpd (running average): 2.089614603056726
# bpd (running average): 2.0897020313631924
# bpd (running average): 2.089821218104547
# bpd (running average): 2.0897270360651525
# bpd (running average): 2.0896828266459484
# bpd (running average): 2.089562066521579
# bpd (running average): 2.08952711110168
# bpd (running average): 2.0894341348426737
# bpd (running average): 2.089476890610619
# bpd (running average): 2.089462072865615
# bpd (running average): 2.0895676662103835
# bpd (running average): 2.0895263503684802
# bpd (running average): 2.0894578708931135
# bpd (running average): 2.0894717059806798
# bpd (running average): 2.089494879820547
# bpd (running average): 2.0894627462425808
# bpd (running average): 2.089455239368289
# bpd (running average): 2.08960506502481
# bpd (running average): 2.0895272696346625
# bpd (running average): 2.0895271636562476
# bpd (running average): 2.0894559109084954
# bpd (running average): 2.0894870752406405
# bpd (running average): 2.0894661143723074
# bpd (running average): 2.089510760125204
# bpd (running average): 2.089498277138202
# bpd (running average): 2.08958002661087
# bpd (running average): 2.0896327782049466
# bpd (running average): 2.0895834405376377
# bpd (running average): 2.089644521154264
# bpd (running average): 2.0895663192625995
# bpd (running average): 2.089498255960426
# bpd (running average): 2.0895041072634073
# bpd (running average): 2.089417792939909
# bpd (running average): 2.0894667083744616
# bpd (running average): 2.089491777625326
# bpd (running average): 2.089558481389388
# bpd (running average): 2.0894476315394046
# bpd (running average): 2.08940289092116
# bpd (running average): 2.089421921933504
# bpd (running average): 2.0891800159502716
# bpd (running average): 2.08901790892696
# bpd (running average): 2.0889661110114845
# bpd (running average): 2.089119368491836
# bpd (running average): 2.089181558777546
# bpd (running average): 2.089204368620526
# bpd (running average): 2.0891980277537288
# bpd (running average): 2.089190568704249
# bpd (running average): 2.0891478747857843
# bpd (running average): 2.0891864248712966
# bpd (running average): 2.089125758592915
# bpd (running average): 2.0891771562480144
# bpd (running average): 2.089157828683425
# bpd (running average): 2.089176530112288
# bpd (running average): 2.089221414853068
# bpd (running average): 2.089243156231927
# bpd (running average): 2.089080981268955
# bpd (running average): 2.0891401448091833
# bpd (running average): 2.089032809945453
# bpd (running average): 2.088822605508765
# bpd (running average): 2.0887474084935973
# bpd (running average): 2.0888379417248943
# bpd (running average): 2.0888328618381524
# bpd (running average): 2.088925863310196
# bpd (running average): 2.0888191702555767
# bpd (running average): 2.0888018254081353
# bpd (running average): 2.0887380254904633
# bpd (running average): 2.088698059480382
# bpd (running average): 2.0886914403219237
# bpd (running average): 2.0887068517330887
# bpd (running average): 2.0888552943733822
# bpd (running average): 2.0889555555056583
# bpd (running average): 2.0889469933400977
# bpd (running average): 2.0889594373283704
# bpd (running average): 2.0889959136263982
# bpd (running average): 2.088982398220161
# bpd (running average): 2.0889698486828836
# bpd (running average): 2.0890240526669506
# bpd (running average): 2.0889242621976747
# bpd (running average): 2.088922778992273
# bpd (running average): 2.0889517539942672
# bpd (running average): 2.0889795430831546
# bpd (running average): 2.089015681881777
# bpd (running average): 2.0888789317766965
# bpd (running average): 2.088934193168116
# bpd (running average): 2.088934213426895
# bpd (running average): 2.0889310241628984
# bpd (running average): 2.088913962049076
# bpd (running average): 2.0888570433133276
# bpd (running average): 2.0888292946802327
# bpd (running average): 2.0888343427124907
# bpd (running average): 2.0889635856501947
# bpd (running average): 2.0889793907588685
# bpd (running average): 2.0890679777513794
# bpd (running average): 2.089073231358679
# bpd (running average): 2.089031581880362
# bpd (running average): 2.088905306306606
# bpd (running average): 2.0888719641009086
# bpd (running average): 2.0890191995450715
# bpd (running average): 2.088998651613665
# bpd (running average): 2.0888255324871694
# bpd (running average): 2.089036590888661
# bpd (running average): 2.0890760532946655
# bpd (running average): 2.089110401036219
# bpd (running average): 2.089052769943623
# bpd (running average): 2.0890841014533077
# bpd (running average): 2.089162450112272
# bpd (running average): 2.089217637262166
# bpd (running average): 2.0890919960816
# bpd (running average): 2.089198374929262
# bpd (running average): 2.089211259710619
# bpd (running average): 2.0892799787042287
# bpd (running average): 2.089342155825851
# bpd (running average): 2.0892388219733062
# bpd (running average): 2.0892614569394783
# bpd (running average): 2.089146284242568
# bpd (running average): 2.089056373491527
# bpd (running average): 2.0888662520031187
# bpd (running average): 2.0887616973601633
# bpd (running average): 2.088858043233526
# bpd (running average): 2.088980295948029
# bpd (running average): 2.0889731710117467
# bpd (running average): 2.0889298014403272
# bpd (running average): 2.08908001597695
# bpd (running average): 2.0891055981968574
# bpd (running average): 2.0892141451704154
# bpd (running average): 2.089258244163939
# bpd (running average): 2.0892744345487375
# bpd (running average): 2.0893184779087735
# bpd (running average): 2.0893500378727063
# bpd (running average): 2.0893987201241875
# bpd (running average): 2.0893474870421778
# bpd (running average): 2.0892325598822836
# bpd (running average): 2.0891531133093033
# bpd (running average): 2.0892135432250027
# bpd (running average): 2.089150603602306
# bpd (running average): 2.0892083310458407
# bpd (running average): 2.089264242949433
# bpd (running average): 2.089214058622164
# bpd (running average): 2.0892724770203372
# bpd (running average): 2.0892311836323363
# bpd (running average): 2.0891434278965946
# bpd (running average): 2.088998269688041
# bpd (running average): 2.088945537804973
# bpd (running average): 2.0889743848707782
# bpd (running average): 2.089008684969615
# bpd (running average): 2.08901297389452
# bpd (running average): 2.0890600914953534
# bpd (running average): 2.0890424123521996
# bpd (running average): 2.088926883140507
# bpd (running average): 2.0888748188379958
# bpd (running average): 2.0887900039478025
# bpd (running average): 2.0889665711729726
# bpd (running average): 2.088854136639037
# bpd (running average): 2.088918065837146
# bpd (running average): 2.088895397305965
# bpd (running average): 2.088841312679684
# bpd (running average): 2.088885686480896
# bpd (running average): 2.0888792140486716
# bpd (running average): 2.088770797116504
# bpd (running average): 2.088791962921307
# bpd (running average): 2.088911787372566
# bpd (running average): 2.0887891799174967
# bpd (running average): 2.08875746892841
# bpd (running average): 2.0888334059817084
# bpd (running average): 2.0889058060372863
# bpd (running average): 2.0890287483598486
# bpd (running average): 2.088965959051827
# bpd (running average): 2.088996342212987
# bpd (running average): 2.0890787928366277
# bpd (running average): 2.0890535238320247
# bpd (running average): 2.0890296814378333
# bpd (running average): 2.088985413703385
# bpd (running average): 2.088968817781786
# bpd (running average): 2.0889180575858095
# bpd (running average): 2.08881871651432
# bpd (running average): 2.088856965503271
# bpd (running average): 2.088897416660858
# bpd (running average): 2.0890135004578365
# bpd (running average): 2.0888726593802964
# bpd (running average): 2.088885185425784
# bpd (running average): 2.088981965381991
# bpd (running average): 2.0890086762934494
# bpd (running average): 2.0889990277092476
# bpd (running average): 2.0890441831941935
# bpd (running average): 2.0890428915490378
# bpd (running average): 2.0889670101649025
# bpd (running average): 2.088955959750341
# bpd (running average): 2.0889272730756336
# bpd (running average): 2.0888754217602954
# bpd (running average): 2.088863309364809
# bpd (running average): 2.088775982571446
# bpd (running average): 2.08883191669135
# bpd (running average): 2.088778852492157
# bpd (running average): 2.088841301819076
# bpd (running average): 2.0888625943140364
# bpd (running average): 2.0889885014164213
# bpd (running average): 2.088921752299964
# bpd (running average): 2.088942101330679
# bpd (running average): 2.089071549361364
# bpd (running average): 2.0890988024756205
# bpd (running average): 2.0891969526199534
# bpd (running average): 2.089105485183955
# bpd (running average): 2.089019871627613
# bpd (running average): 2.088934466598897
# bpd (running average): 2.0888655617328165
# bpd (running average): 2.0888913833128724
# bpd (running average): 2.088804075636695
# bpd (running average): 2.0888578133964497
# bpd (running average): 2.088840083330742
# bpd (running average): 2.088734837332706
# bpd (running average): 2.0887548332146566
# bpd (running average): 2.0887945427840293
# bpd (running average): 2.0888027262691597
# bpd (running average): 2.0886935836221947
# bpd (running average): 2.0887058302457477
# bpd (running average): 2.088588432011804
# bpd (running average): 2.088734237209478
# bpd (running average): 2.088617263951591
# bpd (running average): 2.08878441067959
# bpd (running average): 2.088785030311638
# bpd (running average): 2.088957449398725
# bpd (running average): 2.0890187161303637
# bpd (running average): 2.0890673172648033
# bpd (running average): 2.089087012164471
# bpd (running average): 2.0890721691888086
# bpd (running average): 2.08900198271509
# bpd (running average): 2.088955651208647
# bpd (running average): 2.08903359148113
# bpd (running average): 2.089098566966662
# bpd (running average): 2.0891799456059785
# bpd (running average): 2.089093991851882
# bpd (running average): 2.089184586192454
# bpd (running average): 2.08928960315866
# bpd (running average): 2.089243023610256
# bpd (running average): 2.0891716394481383
# bpd (running average): 2.08926808145809
# bpd (running average): 2.0892097324731616
# bpd (running average): 2.0892446366024204
# bpd (running average): 2.089137012560909
# bpd (running average): 2.0891941724919856
# bpd (running average): 2.089183597333047
# bpd (running average): 2.089195846978045
# bpd (running average): 2.0891950136471262
# bpd (running average): 2.089268884159568
# bpd (running average): 2.089393037440304
# bpd (running average): 2.0893724050566806
# bpd (running average): 2.0893544541570974
# bpd (running average): 2.089278573676666
# bpd (running average): 2.0893175869921623
# bpd (running average): 2.089410878676856
# bpd (running average): 2.089453669703204
# bpd (running average): 2.0895149041767076
# bpd (running average): 2.0893409345859837
# bpd (running average): 2.0894393359966363
# bpd (running average): 2.089480432975017
# bpd (running average): 2.0895254644078443
# bpd (running average): 2.0896571938025983
# bpd (running average): 2.0898146915092446
# bpd (running average): 2.0896485647245147
# bpd (running average): 2.0896372144540525
# bpd (running average): 2.0896355056148104
# bpd (running average): 2.0896302115154333
# bpd (running average): 2.0895673255267337
# bpd (running average): 2.0894497792338793
# bpd (running average): 2.089520168828467
# bpd (running average): 2.089491949939332
# bpd (running average): 2.08940831984347
# bpd (running average): 2.0894886468399516
# bpd (running average): 2.089556822531684
# bpd (running average): 2.0894258229199685
# bpd (running average): 2.089324296011595
# bpd (running average): 2.089207322049773
# bpd (running average): 2.0891323554069405
# bpd (running average): 2.089247848132659
# bpd (running average): 2.089197005589082
# bpd (running average): 2.0892379106611543
# bpd (running average): 2.089251814653418
# bpd (running average): 2.089295517956197
# bpd (running average): 2.089325364040952
# bpd (running average): 2.0892119374157345
# bpd (running average): 2.0892448376315214
# bpd (running average): 2.08915167358426
# bpd (running average): 2.089219553637651
# bpd (running average): 2.08922793010911
# bpd (running average): 2.0892822667787336
# bpd (running average): 2.08914443964156
# bpd (running average): 2.0889978526663096
# bpd (running average): 2.0889612487143667
# bpd (running average): 2.0887828362191088
# bpd (running average): 2.088871991519949
# bpd (running average): 2.0889723158639475
# bpd (running average): 2.088986757878458
# bpd (running average): 2.088976289042061
# bpd (running average): 2.0889382659032534
# bpd (running average): 2.088910359915798
# bpd (running average): 2.0889010515471367
# bpd (running average): 2.0888953916432116
# bpd (running average): 2.0889025016512632
# bpd (running average): 2.08900197476419
# bpd (running average): 2.0890016268308194
# bpd (running average): 2.0889456194445644
# bpd (running average): 2.089070526970023
# bpd (running average): 2.0891667060785917
# bpd (running average): 2.089352558323937
# bpd (running average): 2.08932371072705
# bpd (running average): 2.089301029875855
# bpd (running average): 2.0894806917647566
# bpd (running average): 2.0895627342937666
# bpd (running average): 2.0895714805104197
# bpd (running average): 2.089601164671932
# bpd (running average): 2.089561619670513
# bpd (running average): 2.089580093707164
# bpd (running average): 2.089540168020518
# bpd (running average): 2.089580815480717
# bpd (running average): 2.0897458093221437
# bpd (running average): 2.08976889950158
# bpd (running average): 2.089753115812491
# bpd (running average): 2.0896853881392197
# bpd (running average): 2.0896890140577353
# bpd (running average): 2.0897135538879525
# bpd (running average): 2.0897843394100577
# bpd (running average): 2.089751652705566
# bpd (running average): 2.0898041700115666
# bpd (running average): 2.0898439973261995
# bpd (running average): 2.0899049992063716
# bpd (running average): 2.089952307568446
# bpd (running average): 2.0900567366887715
# bpd (running average): 2.0900227587783347
# bpd (running average): 2.0901117157292117
# bpd (running average): 2.090084044667871
# bpd (running average): 2.0900941576055647
# bpd (running average): 2.089948798170356
# bpd (running average): 2.089963927040829
# bpd (running average): 2.0900229476086123
# bpd (running average): 2.089956397378226
# bpd (running average): 2.0899197015883604
# bpd (running average): 2.0899102104319
# bpd (running average): 2.0899468306319138
# bpd (running average): 2.089922275696088
# bpd (running average): 2.089926628179299
# bpd (running average): 2.089995274329411
# bpd (running average): 2.0899592305627936
# bpd (running average): 2.0899506062923527
# bpd (running average): 2.0900081012684195
# bpd (running average): 2.08993103928159
# bpd (running average): 2.0899745997474652
# bpd (running average): 2.0899489624439593
# bpd (running average): 2.089931342101826
# bpd (running average): 2.0899423554184318
# bpd (running average): 2.0899544173879665
# bpd (running average): 2.089879777073313
# bpd (running average): 2.089843078024052
# bpd (full average): 2.089843078024052

# %% [markdown]
# ## Further Resources
#
# If you're interested in learning more about score-based generative models, the following papers would be a good start:
#
# *   Yang Song, and Stefano Ermon. "[Generative modeling by estimating gradients of the data distribution.](https://arxiv.org/pdf/1907.05600.pdf)" Advances in Neural Information Processing Systems. 2019.
# *    Yang Song, and Stefano Ermon. "[Improved Techniques for Training Score-Based Generative Models.](https://arxiv.org/pdf/2006.09011.pdf)" Advances in Neural Information Processing Systems. 2020.
# * Jonathan Ho, Ajay Jain, and Pieter Abbeel. "[Denoising diffusion probabilistic models.](https://arxiv.org/pdf/2006.11239.pdf)" Advances in Neural Information Processing Systems. 2020.
